# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time

import pandas as pd
import numpy as np

# %%
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
driver = webdriver.Chrome(executable_path=r'D:\Downloads\chromedriver_win32\chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4d1b4088393> in <module>
# ----> 1 options = Options()
#       2 options.headless = True
#       3 options.add_argument("--window-size=1920,1200")
#       4 driver = webdriver.Chrome(executable_path=r'D:\Downloads\chromedriver_win32\chromedriver.exe', options = options)
#
# NameError: name 'Options' is not defined

# %%
df = pd.read_csv("../data/linkedin_Professionals.csv")
df.head(5)
# Out:
#                                                 URLS
# 0          https://www.linkedin.com/in/santosh-vasa/
# 1           https://www.linkedin.com/in/rahulbaddam/
# 2  https://www.linkedin.com/in/christopher-amato-...
# 3  https://www.linkedin.com/in/sanjana-nalawade-8...
# 4              https://www.linkedin.com/in/gipson97/

# %%
for i,url in enumerate(df['URLS']):
    try:
        driver.get(url)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(3)
#         h1 = driver.find_elements_by_id("ember75")
#         h2 = driver.find_elements_by_class_name("pv-about-section")
#         print(h1[0].find_element_by_tag_name("ol").text)
#         h3 = driver.find_elements_by_id("education-section")
#         print(h3[0].text)
        print(driver.page_source)
        break
    except:
        pass
# Out:
# <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
#
#     <title>Santosh Vasa | LinkedIn</title>
#
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb">
#     <meta name="description" content="">
#     <meta name="google" content="notranslate">
#     <meta name="service" content="voyager-web">
#     <meta name="theme-color" content="#ffffff" id="theme-color-meta-tag">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
# ...

# %%
h1[0].find_element_by_tag_name("ol").text
# Out:
# 'Deep Learning\nSee 4 endorsements for Deep Learning\n4\nsai krishna and 3 connections have given endorsements for this skill\nConvolutional Neural Networks (CNN)\nSee 3 endorsements for Convolutional Neural Networks (CNN)\n3\nAdithya C and 2 connections have given endorsements for this skill\nTensorFlow\nSee 3 endorsements for TensorFlow\n3\nAdithya C and 2 connections have given endorsements for this skill'

# %%
pv-about-section
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="c23ce1b8211c381f34310ce58f87ef53", element="65142ea3-666d-4dac-be5c-a1afba58c03b")>>

# %%
pv-skill-categories-section__top-skills pv-profile-section__section-info section-info pb1

# %%
df.head()
# Out:
#                                                 URLS
# 0          https://www.linkedin.com/in/santosh-vasa/
# 1           https://www.linkedin.com/in/rahulbaddam/
# 2  https://www.linkedin.com/in/christopher-amato-...
# 3  https://www.linkedin.com/in/sanjana-nalawade-8...
# 4              https://www.linkedin.com/in/gipson97/
