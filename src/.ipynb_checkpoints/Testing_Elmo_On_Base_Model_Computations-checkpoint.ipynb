# %%
import pandas as pd
import numpy as np
import spacy
import nltk
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.metrics.pairwise import cosine_similarity
import string
import config
from elmo import Elmo
import utils
from utils import tokenize
from utils import Utils
from utils import find_word
from utils import find_word_root
from utils import preprocess_sentence_text
from skill_word import SkillWord
from fetched_word import FetchedWord
from webpage import Webpage
import tqdm

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import numpy as np
import pandas as pd
import nltk
import string
import re
import time
import spacy
from collections import Counter

# %%
elmo = Elmo()
skills = config.SKILLS
tools = utils.Utils()

# %%
skills_df = pd.read_csv("../data/skills.csv")
skills_df = skills_df.drop(columns = ["Unnamed: 0"])

# %%
bert_vocab = list(np.load("../data/bert_vocab.npy"))

# %%
skill_rare_words = []
rare_words = []
skill_words_count = 0
for skill_ind, skill in enumerate(skills_df['summary']):
    text = skills_df['summary'][skill_ind]
    skill_name = skills_df['skills'][skill_ind]
    print("\n\n",skill_name, "\n\n")
    if isinstance(text, float) and np.isnan(text):
        continue
    sentences = preprocess_sentence_text(text)
    embeddings = elmo.run(sentences)
    for i,sentence in enumerate(sentences):
        words = tokenize(sentence)
        skill_words_count = skill_words_count + len(words)
        for word in words:
            if tools.is_rare(word):
                index = words.index(word)
                word_ind = find_word(skill_rare_words, word)
                try:
                    if word_ind >= 0:
                        skill_rare_words[word_ind].update(sentence, embeddings[i][index], index, skill_name)
                    else:
                        sk_word = SkillWord(word, tools.lemmatize(word))
                        sk_word.update(sentence, embeddings[i][index], index, skill_name)
                        skill_rare_words.append(sk_word)
                except:
                    print(word, sentence, i)
                    continue
# Out:
#  Deep Learning
#
#
#
#
#  Convolutional Neural Networks
#
#
#
#
#  TensorFlow
#
#
#
#
#  Machine Learning
#
#
#
#
#  Algorithms
#
#
#
#
#  Computer Vision
#
#
#
#
#  Deep Reinforcement Learning
#
#
#
#
#  Computer Science
#
#
#
#
#  Python
#
#
#
#
#  Matlab
#
#
#
#
#  Recurrent Neural Networks
#
#
#
#
#  Django
#
#
#
#
#  Java
#
#
#
#
#  Keras
#
#
#
#
#  PyTorch
#
#
#
#
#  Neural Networks
#
#
#
#
#  Edge Computing
#
#
#
#
#  OpenCV
#
#
#
#
#  Scikit-Learn
#
#
#
#
#  Natural Language Processing
#
#
#
#
#  Object Detection
#
#
#
#
#  Reinforcement Learning
#
#
#
#
#  Generative Adverserial Networks

# %%
def cosin(emb1, emb2):
    return cosine_similarity(emb1.reshape(1,1024), emb2.reshape(1,1024))

# %%
for word in skill_rare_words:
    print(word)
    embeddings = word.embeddings
    for emb in embeddings:
        for emb2 in embeddings:
            print(cosin(emb, emb2))

# %%
options = Options()
options.add_argument('headless');
driver = webdriver.Chrome(executable_path=r'D:\Downloads\chromedriver_win32\chromedriver.exe', options = options)

# %%
webpage = Webpage("https://www.gov.uk/uk-border-control", driver)
fetched = webpage.process_fetched()

# %%
def process_word(word):
    word = utils.remove_punctuation(word)
    word = utils.lower_case(word)
    word = tools.lemmatize(word)
    return word

# %%
def process_set(all_words):
    li = []
    for word in all_words:
        li.append(process_word(word))
    return list(set(li))

# %%
def test_url(url):
    webpage = Webpage(url, driver)
    fetched = webpage.process_fetched()
    fetched_rare_words = []
    all_words = []
    for tag in fetched.keys():
        if len(fetched[tag]) == 0:
            continue
        embeddings = elmo.run(fetched[tag])
        for i, sentence in enumerate(fetched[tag]):
            words = tokenize(sentence)
            all_words.extend(words)
            for word in words:
                if tools.is_rare(word):
                    index = words.index(word)
                    word_ind = find_word(fetched_rare_words, word)
                    if word_ind >= 0:
                        fetched_rare_words[word_ind].update(sentence, embeddings[i][index], index)
                    else:
                        try:
                            ft_word = FetchedWord(word, tools.lemmatize(word), tag)
                            ft_word.update(sentence, embeddings[i][index], index)
                            fetched_rare_words.append(ft_word)
                        except:
                            print(embeddings.shape, index, sentence, tag)
    return webpage.count,fetched_rare_words, process_set(all_words)

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
def relevance(skill_rare_words, fetched_rare_words):
    matched_words = []
    matched_count = 0
    s_count = []
    f_count = []
    for word in fetched_rare_words:
        index = find_word_root(skill_rare_words, word.root)
        if index >=0:
            matched_words.append(word)
            sim = similarity(word, skill_rare_words[index])[0][0]
            matched_count = matched_count + (0.6 * word.count + 1.0 * skill_rare_words[index].count) * sim
            if config.DEBUG:
                print("Similarity for the word: ",word.word,sim)
            print("Similarity for the word: ",word.word,sim)
            s_count.append(skill_rare_words[index].count)
            f_count.append(word.count)
    return matched_words , matched_count
result,matched_count = relevance(skill_rare_words, fetched_rare_words)
# Out:
# Similarity for the word:  deep 0.95628977
# Similarity for the word:  learning 0.9701619
# Similarity for the word:  applications 0.8129908
# Similarity for the word:  matlab 0.92819554
# Similarity for the word:  learn 0.62642795
# Similarity for the word:  related 0.7465273
# Similarity for the word:  results 0.90312296
# Similarity for the word:  examples 0.588192
# Similarity for the word:  difference 0.6127426
# Similarity for the word:  machine 0.96030456
# Similarity for the word:  create 0.40166298
# Similarity for the word:  train 0.49025095
# Similarity for the word:  models 0.91945106
# Similarity for the word:  recognize 0.49487492
# Similarity for the word:  objects 0.6323399
# Similarity for the word:  example 0.88907003
# Similarity for the word:  object 0.8979031
# Similarity for the word:  detection 0.9097479
# Similarity for the word:  neural 0.9772605
# Similarity for the word:  networks 0.9533144
# Similarity for the word:  predictive 0.9054825
# Similarity for the word:  analytics 0.9364134
# Similarity for the word:  artificial 0.88457286
# Similarity for the word:  intelligence 0.8742859
# Similarity for the word:  reinforcement 0.8582374
# Similarity for the word:  convolutional 0.87171656
# Similarity for the word:  network 0.837796
# Similarity for the word:  traditional 0.7625034
# Similarity for the word:  approach 0.88421214
# Similarity for the word:  length 0.6794702
# Similarity for the word:  reasons 0.38785064
# Similarity for the word:  features 0.8283626
# Similarity for the word:  engineers 0.6286103
# Similarity for the word:  started 0.52732384
# Similarity for the word:  simulink 0.65722126
# Similarity for the word:  practical 0.7508384
# Similarity for the word:  techniques 0.7668262
# Similarity for the word:  web 0.60615903
# Similarity for the word:  technique 0.63409495
# Similarity for the word:  computers 0.6357274
# Similarity for the word:  technology 0.7889132
# Similarity for the word:  enabling 0.6002706
# Similarity for the word:  pedestrian 0.67840755
# Similarity for the word:  devices 0.7415824
# Similarity for the word:  reason 0.48119947
# Similarity for the word:  computer 0.9291205
# Similarity for the word:  model 0.81101584
# Similarity for the word:  learns 0.8747387
# Similarity for the word:  perform 0.9423728
# Similarity for the word:  classification 0.87998927
# Similarity for the word:  tasks 0.93436086
# Similarity for the word:  images 0.7192943
# Similarity for the word:  trained 0.8653831
# Similarity for the word:  labeled 0.7221537
# Similarity for the word:  data 0.97043914
# Similarity for the word:  architectures 0.8139725
# Similarity for the word:  contain 0.4858414
# Similarity for the word:  layers 0.95289546
# Similarity for the word:  recognition 0.8802029
# Similarity for the word:  user 0.72608495
# Similarity for the word:  improved 0.67629755
# Similarity for the word:  automated 0.9023212
# Similarity for the word:  medical 0.78681934
# Similarity for the word:  automatically 0.73321426
# Similarity for the word:  detect 0.7277005
# Similarity for the word:  pedestrians 0.5819311
# Similarity for the word:  locate 0.35469574
# Similarity for the word:  built 0.63384306
# Similarity for the word:  highdimensional 0.6464611
# Similarity for the word:  application 0.8857732
# Similarity for the word:  accurately 0.8718139
# Similarity for the word:  automation 0.8192759
# Similarity for the word:  improve 0.9043354
# Similarity for the word:  detecting 0.8413619
# Similarity for the word:  machines 0.73258966
# Similarity for the word:  speech 0.8098671
# Similarity for the word:  translation 0.8326778
# Similarity for the word:  respond 0.8192303
# Similarity for the word:  methods 0.9029139
# Similarity for the word:  referred 0.64857507
# Similarity for the word:  term 0.83643436
# Similarity for the word:  usually 0.6357945
# Similarity for the word:  refers 0.9144046
# Similarity for the word:  hidden 0.3433596
# Similarity for the word:  manual 0.8348969
# Similarity for the word:  feature 0.75821954
# Similarity for the word:  extraction 0.88198817
# Similarity for the word:  organized 0.48631367
# Similarity for the word:  nodes 0.84814143
# Similarity for the word:  cnn 0.8048197
# Similarity for the word:  convnet 0.7240783
# Similarity for the word:  learned 0.6198323
# Similarity for the word:  input 0.9095464
# Similarity for the word:  architecture 0.68815243
# Similarity for the word:  processing 0.92063195
# Similarity for the word:  cnns 0.8432032
# Similarity for the word:  extracting 0.67790836
# Similarity for the word:  trains 0.40817058
# Similarity for the word:  vision 0.9298794
# Similarity for the word:  filters 0.755687
# Similarity for the word:  applied 0.83143926
# Similarity for the word:  training 0.9113296
# Similarity for the word:  image 0.8489706
# Similarity for the word:  output 0.8655959
# Similarity for the word:  serves 0.6322896
# Similarity for the word:  layer 0.7842386
# Similarity for the word:  increases 0.48913196
# Similarity for the word:  complexity 0.76326036
# Similarity for the word:  complex 0.7861676
# Similarity for the word:  specifically 0.65699846
# Similarity for the word:  starts 0.5567367
# Similarity for the word:  extracted 0.50970787
# Similarity for the word:  categorizes 0.68507695
# Similarity for the word:  performs 0.68770134
# Similarity for the word:  task 0.7212111
# Similarity for the word:  algorithms 0.95515466
# Similarity for the word:  scale 0.62088144
# Similarity for the word:  whereas 0.90322375
# Similarity for the word:  certain 0.7104256
# Similarity for the word:  add 0.60936266
# Similarity for the word:  advantage 0.83970916
# Similarity for the word:  size 0.65145946
# Similarity for the word:  comparing 0.53623986
# Similarity for the word:  categorizing 0.6361666
# Similarity for the word:  classifier 0.2523191
# Similarity for the word:  modeling 0.5771737
# Similarity for the word:  automatic 0.69773173
# Similarity for the word:  variety 0.86120903
# Similarity for the word:  based 0.81487906
# Similarity for the word:  problem 0.75706816
# Similarity for the word:  solve 0.5695641
# Similarity for the word:  amount 0.8155525
# Similarity for the word:  graphics 0.8226962
# Similarity for the word:  units 0.8462721
# Similarity for the word:  process 0.7568752
# Similarity for the word:  consider 0.6356158
# Similarity for the word:  gpu 0.828357
# Similarity for the word:  sense 0.73813045
# Similarity for the word:  generally 0.7918937
# Similarity for the word:  means 0.66512644
# Similarity for the word:  analyze 0.85378057
# Similarity for the word:  ways 0.7183001
# Similarity for the word:  typically 0.54097766
# Similarity for the word:  involves 0.71883684
# Similarity for the word:  start 0.55990726
# Similarity for the word:  containing 0.5216609
# Similarity for the word:  rather 0.7157062
# Similarity for the word:  computation 0.75571406
# Similarity for the word:  interface 0.75762564
# Similarity for the word:  internals 0.49485248
# Similarity for the word:  modified 0.7642344
# Similarity for the word:  functions 0.59902704
# Similarity for the word:  tasked 0.39521277
# Similarity for the word:  vector 0.824204
# Similarity for the word:  acceleration 0.83646864
# Similarity for the word:  understand 0.664932
# Similarity for the word:  explicitly 0.6557597
# Similarity for the word:  toolbox 0.74542403
# Similarity for the word:  apply 0.52908885
# Similarity for the word:  problems 0.8483737
# Similarity for the word:  performing 0.69185877
# Similarity for the word:  users 0.5589668
# Similarity for the word:  simple 0.4707839
# Similarity for the word:  specific 0.69528306
# Similarity for the word:  scene 0.6520071
# Similarity for the word:  multiple 0.89237416
# Similarity for the word:  toolboxes 0.6595274
# Similarity for the word:  expert 0.57829523
# Similarity for the word:  deploy 0.48974892
# Similarity for the word:  servers 0.8190714
# Similarity for the word:  embedded 0.9066858
# Similarity for the word:  build 0.7969469
# Similarity for the word:  parameters 0.7920996
# Similarity for the word:  gain 0.84492487
# Similarity for the word:  enables 0.7259034
# Similarity for the word:  domain 0.5796824
# Similarity for the word:  experts 0.494244
# Similarity for the word:  label 0.4040662
# Similarity for the word:  automate 0.590695
# Similarity for the word:  domains 0.8875549
# Similarity for the word:  programming 0.7779709
# Similarity for the word:  environment 0.75807095
# Similarity for the word:  range 0.90722734
# Similarity for the word:  deploying 0.48637474
# Similarity for the word:  clusters 0.5639841
# Similarity for the word:  statistics 0.8189056
# Similarity for the word:  mathworks 0.8473454
# Similarity for the word:  engineering 0.8218422
# Similarity for the word:  mathematical 0.83079946
# Similarity for the word:  computing 0.83033156
# Similarity for the word:  software 0.8624722

# %%
web_count,fetched_rare_words, all_words = test_url("https://www.theblondeabroad.com/locals-guide-to-boston/")
result, count = relevance(skill_rare_words, fetched_rare_words)
count/total(fetched_rare_words)
# Out:
# Similarity for the word:  interactions 0.6667107
# Similarity for the word:  library 0.8645438
# Similarity for the word:  sample 0.64079034
# Similarity for the word:  layers 0.85089755
# Similarity for the word:  related 0.6887226
# Similarity for the word:  2020 0.6450329
# Similarity for the word:  featuring 0.4968673
# Similarity for the word:  reason 0.37675828
# Similarity for the word:  size 0.72711504
# Similarity for the word:  plate 0.71498436
# Similarity for the word:  transportation 0.71649885
# Similarity for the word:  especially 0.71155155
# Similarity for the word:  machine 0.6624979
# Similarity for the word:  start 0.55467856
# Similarity for the word:  add 0.639161
# Similarity for the word:  additional 0.614058
# Similarity for the word:  ubers 0.6325377
# Similarity for the word:  located 0.7928926
# Similarity for the word:  host 0.47411284
# Similarity for the word:  events 0.59372956
# Similarity for the word:  architecture 0.62915576
# Similarity for the word:  edge 0.7261872
# Similarity for the word:  modern 0.71839446
# Similarity for the word:  tends 0.66628397
# Similarity for the word:  scene 0.56262374
# Similarity for the word:  usually 0.51624584
# Similarity for the word:  features 0.7268378
# Similarity for the word:  views 0.61708903
# Similarity for the word:  condition 0.4401747
# Similarity for the word:  occurred 0.60068655
# Similarity for the word:  activities 0.39805508
# Similarity for the word:  map 0.47243163
# Similarity for the word:  built 0.4289232
# Similarity for the word:  completed 0.36941144
# Similarity for the word:  shopping 0.61942047
# Similarity for the word:  stores 0.3191234
# Similarity for the word:  tend 0.77446395
# Similarity for the word:  formal 0.45055664
# Similarity for the word:  willow 0.6854473
# Similarity for the word:  deal 0.36438882
# Similarity for the word:  base 0.27756593
# Similarity for the word:  bound 0.303358
# Similarity for the word:  strong 0.554137
# Similarity for the word:  experience 0.66940624
# Similarity for the word:  started 0.46433663
# Similarity for the word:  variations 0.7060106
# Similarity for the word:  inspired 0.7894522
# Similarity for the word:  view 0.53041553
# Similarity for the word:  backend 0.4225359
# Similarity for the word:  residents 0.8031827
# Similarity for the word:  mountains 0.8039613
# Similarity for the word:  sense 0.64621633
# Similarity for the word:  provides 0.6319995
# Similarity for the word:  activity 0.58408976
# Similarity for the word:  email 0.6953609
# Similarity for the word:  save 0.75496155
# Similarity for the word:  learn 0.52917206
# Similarity for the word:  data 0.75964564
# Similarity for the word:  processed 0.42362058
# 0.14742636659720515

# %%
web_count,fetched_rare_words, all_words = test_url("https://www.mathworks.com/discovery/deep-learning.html")
result, count = relevance(skill_rare_words, fetched_rare_words)
count/(total(fetched_rare_words))
# Out:
# Similarity for the word:  deep 0.95628977
# Similarity for the word:  learning 0.9701619
# Similarity for the word:  applications 0.8129908
# Similarity for the word:  matlab 0.92819554
# Similarity for the word:  learn 0.62642795
# Similarity for the word:  related 0.7465273
# Similarity for the word:  results 0.90312296
# Similarity for the word:  examples 0.588192
# Similarity for the word:  difference 0.6127426
# Similarity for the word:  machine 0.96030456
# Similarity for the word:  create 0.40166298
# Similarity for the word:  train 0.49025095
# Similarity for the word:  models 0.91945106
# Similarity for the word:  recognize 0.49487492
# Similarity for the word:  objects 0.6323399
# Similarity for the word:  example 0.88907003
# Similarity for the word:  object 0.8979031
# Similarity for the word:  detection 0.9097479
# Similarity for the word:  neural 0.9772605
# Similarity for the word:  networks 0.9533144
# Similarity for the word:  predictive 0.9054825
# Similarity for the word:  analytics 0.9364134
# Similarity for the word:  artificial 0.88457286
# Similarity for the word:  intelligence 0.8742859
# Similarity for the word:  reinforcement 0.8582374
# Similarity for the word:  convolutional 0.87171656
# Similarity for the word:  network 0.837796
# Similarity for the word:  traditional 0.7625034
# Similarity for the word:  approach 0.88421214
# Similarity for the word:  length 0.6794702
# Similarity for the word:  reasons 0.38785064
# Similarity for the word:  features 0.8283626
# Similarity for the word:  engineers 0.6286103
# Similarity for the word:  started 0.52732384
# Similarity for the word:  simulink 0.65722126
# Similarity for the word:  practical 0.7508384
# Similarity for the word:  techniques 0.7668262
# Similarity for the word:  web 0.60615903
# Similarity for the word:  technique 0.63409495
# Similarity for the word:  computers 0.6357274
# Similarity for the word:  technology 0.7889132
# Similarity for the word:  enabling 0.6002706
# Similarity for the word:  pedestrian 0.67840755
# Similarity for the word:  devices 0.7415824
# Similarity for the word:  reason 0.48119947
# Similarity for the word:  computer 0.9291205
# Similarity for the word:  model 0.81101584
# Similarity for the word:  learns 0.8747387
# Similarity for the word:  perform 0.9423728
# Similarity for the word:  classification 0.87998927
# Similarity for the word:  tasks 0.93436086
# Similarity for the word:  images 0.7192943
# Similarity for the word:  trained 0.8653831
# Similarity for the word:  labeled 0.7221537
# Similarity for the word:  data 0.97043914
# Similarity for the word:  architectures 0.8139725
# Similarity for the word:  contain 0.4858414
# Similarity for the word:  layers 0.95289546
# Similarity for the word:  recognition 0.8802029
# Similarity for the word:  user 0.72608495
# Similarity for the word:  improved 0.67629755
# Similarity for the word:  automated 0.9023212
# Similarity for the word:  medical 0.78681934
# Similarity for the word:  automatically 0.73321426
# Similarity for the word:  detect 0.7277005
# Similarity for the word:  pedestrians 0.5819311
# Similarity for the word:  locate 0.35469574
# Similarity for the word:  built 0.63384306
# Similarity for the word:  highdimensional 0.6464611
# Similarity for the word:  application 0.8857732
# Similarity for the word:  accurately 0.8718139
# Similarity for the word:  automation 0.8192759
# Similarity for the word:  improve 0.9043354
# Similarity for the word:  detecting 0.8413619
# Similarity for the word:  machines 0.73258966
# Similarity for the word:  speech 0.8098671
# Similarity for the word:  translation 0.8326778
# Similarity for the word:  respond 0.8192303
# Similarity for the word:  methods 0.9029139
# Similarity for the word:  referred 0.64857507
# Similarity for the word:  term 0.83643436
# Similarity for the word:  usually 0.6357945
# Similarity for the word:  refers 0.9144046
# Similarity for the word:  hidden 0.3433596
# Similarity for the word:  manual 0.8348969
# Similarity for the word:  feature 0.75821954
# Similarity for the word:  extraction 0.88198817
# Similarity for the word:  organized 0.48631367
# Similarity for the word:  nodes 0.84814143
# Similarity for the word:  cnn 0.8048197
# Similarity for the word:  convnet 0.7240783
# Similarity for the word:  learned 0.6198323
# Similarity for the word:  input 0.9095464
# Similarity for the word:  architecture 0.68815243
# Similarity for the word:  processing 0.92063195
# Similarity for the word:  cnns 0.8432032
# Similarity for the word:  extracting 0.67790836
# Similarity for the word:  trains 0.40817058
# Similarity for the word:  vision 0.9298794
# Similarity for the word:  filters 0.755687
# Similarity for the word:  applied 0.83143926
# Similarity for the word:  training 0.9113296
# Similarity for the word:  image 0.8489706
# Similarity for the word:  output 0.8655959
# Similarity for the word:  serves 0.6322896
# Similarity for the word:  layer 0.7842386
# Similarity for the word:  increases 0.48913196
# Similarity for the word:  complexity 0.76326036
# Similarity for the word:  complex 0.7861676
# Similarity for the word:  specifically 0.65699846
# Similarity for the word:  starts 0.5567367
# Similarity for the word:  extracted 0.50970787
# Similarity for the word:  categorizes 0.68507695
# Similarity for the word:  performs 0.68770134
# Similarity for the word:  task 0.7212111
# Similarity for the word:  algorithms 0.95515466
# Similarity for the word:  scale 0.62088144
# Similarity for the word:  whereas 0.90322375
# Similarity for the word:  certain 0.7104256
# Similarity for the word:  add 0.60936266
# Similarity for the word:  advantage 0.83970916
# Similarity for the word:  size 0.65145946
# Similarity for the word:  comparing 0.53623986
# Similarity for the word:  categorizing 0.6361666
# Similarity for the word:  classifier 0.2523191
# Similarity for the word:  modeling 0.5771737
# Similarity for the word:  automatic 0.69773173
# Similarity for the word:  variety 0.86120903
# Similarity for the word:  based 0.81487906
# Similarity for the word:  problem 0.75706816
# Similarity for the word:  solve 0.5695641
# Similarity for the word:  amount 0.8155525
# Similarity for the word:  graphics 0.8226962
# Similarity for the word:  units 0.8462721
# Similarity for the word:  process 0.7568752
# Similarity for the word:  consider 0.6356158
# Similarity for the word:  gpu 0.828357
# Similarity for the word:  sense 0.73813045
# Similarity for the word:  generally 0.7918937
# Similarity for the word:  means 0.66512644
# Similarity for the word:  analyze 0.85378057
# Similarity for the word:  ways 0.7183001
# Similarity for the word:  typically 0.54097766
# Similarity for the word:  involves 0.71883684
# Similarity for the word:  start 0.55990726
# Similarity for the word:  containing 0.5216609
# Similarity for the word:  rather 0.7157062
# Similarity for the word:  computation 0.75571406
# Similarity for the word:  interface 0.75762564
# Similarity for the word:  internals 0.49485248
# Similarity for the word:  modified 0.7642344
# Similarity for the word:  functions 0.59902704
# Similarity for the word:  tasked 0.39521277
# Similarity for the word:  vector 0.824204
# Similarity for the word:  acceleration 0.83646864
# Similarity for the word:  understand 0.664932
# Similarity for the word:  explicitly 0.6557597
# Similarity for the word:  toolbox 0.74542403
# Similarity for the word:  apply 0.52908885
# Similarity for the word:  problems 0.8483737
# Similarity for the word:  performing 0.69185877
# Similarity for the word:  users 0.5589668
# Similarity for the word:  simple 0.4707839
# Similarity for the word:  specific 0.69528306
# Similarity for the word:  scene 0.6520071
# Similarity for the word:  multiple 0.89237416
# Similarity for the word:  toolboxes 0.6595274
# Similarity for the word:  expert 0.57829523
# Similarity for the word:  deploy 0.48974892
# Similarity for the word:  servers 0.8190714
# Similarity for the word:  embedded 0.9066858
# Similarity for the word:  build 0.7969469
# Similarity for the word:  parameters 0.7920996
# Similarity for the word:  gain 0.84492487
# Similarity for the word:  enables 0.7259034
# Similarity for the word:  domain 0.5796824
# Similarity for the word:  experts 0.494244
# Similarity for the word:  label 0.4040662
# Similarity for the word:  automate 0.590695
# Similarity for the word:  domains 0.8875549
# Similarity for the word:  programming 0.7779709
# Similarity for the word:  environment 0.75807095
# Similarity for the word:  range 0.90722734
# Similarity for the word:  deploying 0.48637474
# Similarity for the word:  clusters 0.5639841
# Similarity for the word:  statistics 0.8189056
# Similarity for the word:  mathworks 0.8473454
# Similarity for the word:  engineering 0.8218422
# Similarity for the word:  mathematical 0.83079946
# Similarity for the word:  computing 0.83033156
# Similarity for the word:  software 0.8624722
# 0.954162732259087

# %%
skill_words_count
# Out:
# 3330

# %%
def total(words):
    count = 0
    for word in words:
        count =count + word.count
    return count

# %%
matched_words = []
matched_count = 0
s_count = []
f_count = []
for word in fetched_rare_words:
    index = find_word_root(skill_rare_words, word.root)
    if index >=0:
        matched_words.append(word)
        matched_count = matched_count + (1.0 * word.count + 1.0 * skill_rare_words[index].count)
        print(word.word,similarity(word, skill_rare_words[index]))
        s_count.append(skill_rare_words[index].count)
        f_count.append(word.count)
# Out:
# interactions [[0.6667107]]
# library [[0.8645438]]
# sample [[0.64079034]]
# layers [[0.85089755]]
# related [[0.6887226]]
# 2020 [[0.6450329]]
# featuring [[0.4968673]]
# reason [[0.37675828]]
# size [[0.72711504]]
# plate [[0.71498436]]
# transportation [[0.71649885]]
# especially [[0.71155155]]
# machine [[0.6624979]]
# start [[0.55467856]]
# add [[0.639161]]
# additional [[0.614058]]
# ubers [[0.6325377]]
# located [[0.7928926]]
# host [[0.47411284]]
# events [[0.59372956]]
# architecture [[0.62915576]]
# edge [[0.7261872]]
# modern [[0.71839446]]
# tends [[0.66628397]]
# scene [[0.56262374]]
# usually [[0.51624584]]
# features [[0.7268378]]
# views [[0.61708903]]
# condition [[0.4401747]]
# occurred [[0.60068655]]
# activities [[0.39805508]]
# map [[0.47243163]]
# built [[0.4289232]]
# completed [[0.36941144]]
# shopping [[0.61942047]]
# stores [[0.3191234]]
# tend [[0.77446395]]
# formal [[0.45055664]]
# willow [[0.6854473]]
# deal [[0.36438882]]
# base [[0.27756593]]
# bound [[0.303358]]
# strong [[0.554137]]
# experience [[0.66940624]]
# started [[0.46433663]]
# variations [[0.7060106]]
# inspired [[0.7894522]]
# view [[0.53041553]]
# backend [[0.4225359]]
# residents [[0.8031827]]
# mountains [[0.8039613]]
# sense [[0.64621633]]
# provides [[0.6319995]]
# activity [[0.58408976]]
# email [[0.6953609]]
# save [[0.75496155]]
# learn [[0.52917206]]
# data [[0.75964564]]
# processed [[0.42362058]]

# %%
def similarity(word1, word2):
    emb1 = np.mean(word1.embeddings, axis=0)
    emb2 = np.mean(word2.embeddings, axis=0)
    return cosine_similarity(emb1.reshape(1,1024), emb2.reshape(1,1024))

# %%
cosin(skill_rare_words[0].embeddings[0], np.mean(np.array(skill_rare_words[0].embeddings),axis=0))
# Out:
# array([[0.8931578]], dtype=float32)

# %%
# Out:
# array([-0.07569011,  0.08175742,  0.7788481 , ...,  0.05644303,
#         0.2304977 ,  0.18030009], dtype=float32)
