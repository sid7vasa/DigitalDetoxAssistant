# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import elmo
# %load_ext autoreload

# %%
# %autoreload 1
import importlib
from utils import tokenize
from utils import Utils
from utils import find_word
from utils import find_word_root
import utils
from fetched_word import FetchedWord
import config
from webpage import Webpage
import inference_tools
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
driver = config.DRIVER
elmo = elmo.Elmo()
tools = Utils()
# Out:
# Using real Elmo?

# %% [markdown]
# ### Opens the file that contains rare skill words.
#
# - Returns a list of custom objects called SkillWords.
# - Each object is an uncommon word(rare word) that is extracted from the knowledge base fetched from wikipedia.
# - This object along with word contains the following :
# * "Word root",
# * "Sentence in which it was used",
# * "Embeddings from elmo",
# * "Indices of their presence in sentences" ,
# * "which skill it belongs to",
# * "number of times it occured(count)"

# %%
with open(config.SKILL_WORD_PATH, 'rb') as handle:
    skill_rare_words = pickle.load(handle)

# %% [markdown]
# #### Opens the file that contains synthetically prepared dataset with urls that are related to topics such as
#
# - Shopping
# - Entertainment
# - Travel

# %%
other_df = pd.read_excel("../data/web_history/other_website_history_xl.xls")

# %%
other_df.head()
# Out:
#                                      URL  \
# 0            https://ohthatfilmblog.com/
# 1          https://www.themovieblog.com/
# 2         https://www.movie-blogger.com/
# 3  https://blogging.org/top-movie-blogs/
# 4                  https://thefilm.blog/
#
#                                                Title          Visit Time  \
# 0  Oh! That Film Blog | The ramblings of a self c... 2021-12-03 14:04:00
# 1  The Movie Blog | The Official Home of Correct ... 2021-12-03 14:04:00
# 2  Movie-Blogger.com | The No.1 Independent Movie... 2021-12-03 14:04:00
# 3  Top 10 Movie Blogs on the Internet Today | Mov... 2021-12-03 14:04:00
# 4  The Film Blog | The official blog of everythin... 2021-12-03 14:04:00
#
#    Visit Count Visited From Visit Type Web Browser User Profile  \
# 0            1          NaN       Link      Chrome      welcome
# 1            1          NaN       Link      Chrome      welcome
# 2            1          NaN       Link      Chrome      welcome
# 3            1          NaN       Link      Chrome      welcome
# 4            1          NaN       Link      Chrome      welcome
#
#   Browser Profile  URL Length  Typed Count  \
# 0         Default          27            0
# 1         Default          29            0
# 2         Default          30            0
# 3         Default          37            0
# 4         Default          21            0
#
#                                         History File  Record ID
# 0  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12382
# 1  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12381
# 2  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12380
# 3  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12379
# 4  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12378

# %% [markdown]
# #### Opens the file that contains synthetically prepared dataset with urls that are related to an example skill set

# %%
skills_df = pd.read_excel("../data/web_history/synthetic_data_490_xl.xls")

# %%
skills_df.head()
# Out:
#                                                URL  \
# 0  https://www.tensorflow.org/tutorials/images/cnn
# 1                      https://www.tensorflow.org/
# 2         https://en.wikipedia.org/wiki/TensorFlow
# 3         https://github.com/tensorflow/tensorflow
# 4                      https://www.tensorflow.org/
#
#                                               TITILE        Visited_time    1  \
# 0  Convolutional Neural Network (CNN)  |  TensorF... 2021-12-03 03:39:00  2.0
# 1                                         TensorFlow 2021-12-03 03:39:00  2.0
# 2                             TensorFlow - Wikipedia 2021-12-03 03:38:00  1.0
# 3  tensorflow/tensorflow: An Open Source Machine ... 2021-12-03 03:38:00  1.0
# 4                                         TensorFlow 2021-12-03 03:38:00  2.0
#
#      2     3       4        5        6     7    8  \
# 0  NaN  Link  Chrome  welcome  Default  47.0  0.0
# 1  NaN  Link  Chrome  welcome  Default  27.0  0.0
# 2  NaN  Link  Chrome  welcome  Default  40.0  0.0
# 3  NaN  Link  Chrome  welcome  Default  40.0  0.0
# 4  NaN  Link  Chrome  welcome  Default  27.0  0.0
#
#                                                    9     10
# 0  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12121
# 1  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12120
# 2  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12119
# 3  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12118
# 4  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12117

# %%
urls = list(other_df['URL'])
for i, url in enumerate(urls):
    if i == 1:
        break
    _, fetched_words, _ = inference_tools.test_url(elmo, url)
# Out:
# Processing Text from the web page
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27228/2265715973.py in <module>
#       3     if i == 1:
#       4         break
# ----> 5     _, fetched_words, _ = inference_tools.test_url(elmo, url)
#       6
#       7
#
# ~\OneDrive\Documents\GitHub\DIGITAL_DETOX_ASSISTANT\src\inference_tools.py in test_url(elmo, url)
#      45         if len(fetched[tag]) == 0:
#      46             continue
# ---> 47         embeddings = elmo.run(fetched[tag])
#      48         for i, sentence in enumerate(fetched[tag]):
#      49             words = tokenize(sentence)
#
# AttributeError: module 'elmo' has no attribute 'run'

# %%
fetched_words
# Out:
# [ohoh [1 h1],
#  blogblog [3 h1],
#  jamjam [2 h1],
#  legacylegacy [1 h1],
#  20212021 [11 h1],
#  widowwidow [1 h1],
#  quietquiet [3 h1],
#  20202020 [4 h1],
#  cruellacruella [2 h1],
#  windowwindow [1 h1],
#  wishwish [2 h1],
#  deaddead [2 h1],
#  mitchellsmitchells [1 h1],
#  vsvs [2 h1],
#  machinesmachines [1 h1],
#  stowawaystowaway [2 h1],
#  93rd93rd [1 h1],
#  annualannual [2 h1],
#  academyacademy [2 h1],
#  thunderthunder [1 h1],
#  concreteconcrete [1 h1],
#  cowboycowboy [1 h1],
#  cherrycherry [3 h1],
#  followfollow [5 h1],
#  viavia [1 h1],
#  emailemail [3 h1],
#  recentrecent [1 h1],
#  tweetstweets [1 h1],
#  goodreadsgoodreads [1 h1],
#  archivesarchives [1 h1],
#  blogsblogs [1 h1],
#  ramblingsramblings [1 h2],
#  selfself [1 h2],
#  confessedconfessed [1 h2],
#  cinemacinema [2 h2],
#  addictaddict [1 h2],
#  reviewsreviews [4 span],
#  reportreport [2 span],
#  adad [2 span],
#  kidkid [1 p],
#  growinggrowing [3 p],
#  90s90s [1 p],
#  unavoidableunavoidable [1 p],
#  combinationcombination [1 p],
#  michaelmichael [1 p],
#  jordanjordan [1 p],
#  sportssports [1 p],
#  starstar [2 p],
#  looneylooney [1 p],
#  tunestunes [1 p],
#  characterscharacters [1 p],
#  1930s1930s [1 p],
#  smashsmash [1 p],
#  hithit [2 p],
#  moviemovie [1 p],
#  wasntwasnt [1 p],
#  actuallyactually [3 p],
#  continuecontinue [1 p],
#  readingreading [1 p],
#  hellohello [1 p],
#  deardear [1 p],
#  readersreaders [1 p],
#  missmiss [1 p],
#  fairfair [1 p],
#  probablyprobably [1 p],
#  wontwont [1 p],
#  registeredregistered [1 p],
#  absenceabsence [1 p],
#  reviewreview [1 p],
#  decideddecided [1 p],
#  mojomojo [1 p],
#  hadnthadnt [1 p],
#  writingwriting [1 p],
#  castcast [1 p],
#  prepre [1 p],
#  covid19covid19 [2 p],
#  hellhell [2 p],
#  theatrestheatres [1 p],
#  tenten [1 p],
#  dozendozen [1 p],
#  tailtail [1 p],
#  dontdont [1 p],
#  whetherwhether [1 p],
#  reflectingreflecting [1 p],
#  couplecouple [1 p],
#  purepure [1 p],
#  coincidencecoincidence [1 p],
#  lotlot [1 p],
#  moviesmovies [2 p],
#  iveive [2 p],
#  watchingwatching [2 p],
#  recentlyrecently [1 p],
#  isolationisolation [1 p],
#  imim [4 p],
#  whisperwhisper [1 p],
#  quietlyquietly [1 p],
#  nobodynobody [1 p],
#  freaksfreaks [1 p],
#  19961996 [1 p],
#  actionaction [1 p],
#  101101 [1 p],
#  dalmatiansdalmatians [1 p],
#  hugesthugest [1 p],
#  cinematiccinematic [2 p],
#  crimecrime [1 p],
#  meanmean [1 p],
#  haventhavent [1 p],
#  experiencedexperienced [1 p],
#  gloryglory [1 p],
#  glennglenn [1 p],
#  vilvil [1 p],
#  fondfond [1 p],
#  memoriesmemories [1 p],
#  19611961 [1 p],
#  hollywoodhollywood [2 p],
#  adaptingadapting [2 p],
#  novelsnovels [1 p],
#  featurefeature [1 p],
#  whilstwhilst [2 p],
#  absolutelyabsolutely [1 p],
#  amazingamazing [1 p],
#  tendtend [2 p],
#  suffersuffer [1 p],
#  sharedshared [1 p],
#  fatefate [1 p],
#  rushedrushed [1 p],
#  strippedstripped [1 p],
#  richnessrichness [1 p],
#  sourcesource [1 p],
#  materialmaterial [1 p],
#  flashyflashy [1 p],
#  thrillerthriller [1 p],
#  consideringconsidering [1 p],
#  hugehuge [1 p],
#  surprisedsurprised [1 p],
#  realiserealise [1 p],
#  decadedecade [2 p],
#  performancesperformances [2 p],
#  angelinaangelina [1 p],
#  joliejolie [1 p],
#  outingsoutings [1 p],
#  disneysdisneys [1 p],
#  iconiciconic [1 p],
#  villainvillain [1 p],
#  maleficentmaleficent [2 p],
#  mistressmistress [1 p],
#  evilevil [1 p],
#  prettypretty [1 p],
#  neutralneutral [1 p],
#  flatflat [1 p],
#  dislikeddisliked [1 p],
#  stagestage [1 p],
#  adultadult [1 p],
#  admitadmit [1 p],
#  pacepace [1 p],
#  animatedanimated [1 p],
#  featuresfeatures [1 p],
#  particularlyparticularly [1 p],
#  proudproud [1 p],
#  efforteffort [1 p],
#  disneydisney [1 p],
#  pixarpixar [1 p],
#  releaserelease [1 p],
#  elseelse [1 p],
#  experiencingexperiencing [1 p],
#  adolescenceadolescence [1 p],
#  naturalnatural [1 p],
#  gravitategravitate [1 p],
#  towardstowards [1 p],
#  detaildetail [1 p],
#  painspains [1 p],
#  eventsevents [1 p],
#  familiarfamiliar [1 p],
#  rarelyrarely [1 p],
#  dramaticdramatic [1 p],
#  screenscreen [1 p],
#  narrativesnarratives [1 p],
#  basketballbasketball [1 p],
#  diariesdiaries [1 p],
#  thirteenthirteen [1 p],
#  kidskids [1 p],
#  oscarsoscars [1 p],
#  weekendweekend [1 p],
#  couldntcouldnt [1 p],
#  baffledbaffled [1 p],
#  sundaysunday [1 p],
#  talkingtalking [2 p],
#  anthonyanthony [1 p],
#  hopkinshopkins [1 p],
#  shockshock [1 p],
#  actoractor [1 p],
#  chadwickchadwick [1 p],
#  bosemanboseman [1 p],
#  upsetupset [1 p],
#  deserveddeserved [1 p],
#  handfulhandful [1 p],
#  decisionsdecisions [1 p],
#  guysguys [1 p],
#  bloodybloody [1 p],
#  somehowsomehow [1 p],
#  managedmanaged [2 p],
#  pandemicpandemic [1 p],
#  curtailcurtail [1 p],
#  laidlaid [1 p],
#  wastewaste [1 p],
#  ceremoniesceremonies [1 p],
#  sucksuck [1 p],
#  melissamelissa [1 p],
#  mccarthymccarthy [1 p],
#  personalpersonal [1 p],
#  relationshiprelationship [1 p],
#  actressactress [1 p],
#  seemsseems [1 p],
#  stepstep [1 p],
#  forwardforward [1 p],
#  stepssteps [1 p],
#  shesshes [1 p],
#  plentyplenty [1 p],
#  bridesmaidsbridesmaids [1 p],
#  heatheat [1 p],
#  forgiveforgive [1 p],
#  invitesinvites [1 p],
#  subculturesubculture [1 p],
#  previouslypreviously [1 p],
#  watchwatch [2 p],
#  documentarydocumentary [1 p],
#  azaz [1 p],
#  stylestyle [1 p],
#  subjectsubject [1 p],
#  entirelyentirely [1 p],
#  bunchbunch [1 p],
#  oscaroscar [1 p],
#  nominatednominated [1 p],
#  treattreat [1 p],
#  tasktask [2 p],
#  pokemonpokemon [1 p],
#  tata [1 p],
#  catchcatch [1 p],
#  nearlynearly [1 p],
#  completecomplete [1 p],
#  categorycategory [1 p],
#  checkcheck [1 p],
#  listlist [1 p],
#  florianflorian [1 p],
#  zellerszellers [1 p],
#  logginglogging [1 p],
#  netflixnetflix [1 p],
#  amazonamazon [1 p],
#  primeprime [1 p],
#  contentcontent [1 p],
#  naturenature [1 p],
#  weekweek [1 p],
#  kindkind [1 p],
#  programmingprogramming [1 p],
#  appleapple [1 p],
#  poppop [1 p],
#  platformplatform [1 p],
#  enterenter [1 p],
#  addressaddress [1 p],
#  receivereceive [1 p],
#  notificationsnotifications [1 p],
#  joinjoin [1 p],
#  17001700 [1 p],
#  followersfollowers [1 p]]
