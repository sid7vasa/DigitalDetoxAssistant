# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import elmo
import tqdm
# %load_ext autoreload

# %%
from tqdm import tqdm

# %%
# %autoreload 1
import importlib
from utils import tokenize
from utils import Utils
from utils import find_word
from utils import find_word_root
import utils
from fetched_word import FetchedWord
import config
from webpage import Webpage
import inference_tools

# %%
driver = config.DRIVER
elmo = elmo.Elmo()
tools = Utils()
# Out:
# Using real Elmo?

# %% [markdown]
# ### Opens the file that contains rare skill words.
#
# - Returns a list of custom objects called SkillWords.
# - Each object is an uncommon word(rare word) that is extracted from the knowledge base fetched from wikipedia.
# - This object along with word contains the following :
# * "Word root",
# * "Sentence in which it was used",
# * "Embeddings from elmo",
# * "Indices of their presence in sentences" ,
# * "which skill it belongs to",
# * "number of times it occured(count)"

# %%
with open(config.SKILL_WORD_PATH, 'rb') as handle:
    skill_rare_words = pickle.load(handle)

# %% [markdown]
# #### Opens the file that contains synthetically prepared dataset with urls that are related to topics such as
#
# - Shopping
# - Entertainment
# - Travel

# %%
other_df = pd.read_excel("../data/web_history/other_website_history_xl.xls")

# %%
other_df.head()
# Out:
#                                      URL  \
# 0            https://ohthatfilmblog.com/
# 1          https://www.themovieblog.com/
# 2         https://www.movie-blogger.com/
# 3  https://blogging.org/top-movie-blogs/
# 4                  https://thefilm.blog/
#
#                                                Title          Visit Time  \
# 0  Oh! That Film Blog | The ramblings of a self c... 2021-12-03 14:04:00
# 1  The Movie Blog | The Official Home of Correct ... 2021-12-03 14:04:00
# 2  Movie-Blogger.com | The No.1 Independent Movie... 2021-12-03 14:04:00
# 3  Top 10 Movie Blogs on the Internet Today | Mov... 2021-12-03 14:04:00
# 4  The Film Blog | The official blog of everythin... 2021-12-03 14:04:00
#
#    Visit Count Visited From Visit Type Web Browser User Profile  \
# 0            1          NaN       Link      Chrome      welcome
# 1            1          NaN       Link      Chrome      welcome
# 2            1          NaN       Link      Chrome      welcome
# 3            1          NaN       Link      Chrome      welcome
# 4            1          NaN       Link      Chrome      welcome
#
#   Browser Profile  URL Length  Typed Count  \
# 0         Default          27            0
# 1         Default          29            0
# 2         Default          30            0
# 3         Default          37            0
# 4         Default          21            0
#
#                                         History File  Record ID
# 0  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12382
# 1  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12381
# 2  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12380
# 3  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12379
# 4  C:\Users\welcome\AppData\Local\Google\Chrome\U...      12378

# %% [markdown]
# #### Opens the file that contains synthetically prepared dataset with urls that are related to an example skill set

# %%
skills_df = pd.read_excel("../data/web_history/synthetic_data_490_xl.xls")

# %%
skills_df.head()
# Out:
#                                                URL  \
# 0  https://www.tensorflow.org/tutorials/images/cnn
# 1                      https://www.tensorflow.org/
# 2         https://en.wikipedia.org/wiki/TensorFlow
# 3         https://github.com/tensorflow/tensorflow
# 4                      https://www.tensorflow.org/
#
#                                               TITILE        Visited_time    1  \
# 0  Convolutional Neural Network (CNN)  |  TensorF... 2021-12-03 03:39:00  2.0
# 1                                         TensorFlow 2021-12-03 03:39:00  2.0
# 2                             TensorFlow - Wikipedia 2021-12-03 03:38:00  1.0
# 3  tensorflow/tensorflow: An Open Source Machine ... 2021-12-03 03:38:00  1.0
# 4                                         TensorFlow 2021-12-03 03:38:00  2.0
#
#      2     3       4        5        6     7    8  \
# 0  NaN  Link  Chrome  welcome  Default  47.0  0.0
# 1  NaN  Link  Chrome  welcome  Default  27.0  0.0
# 2  NaN  Link  Chrome  welcome  Default  40.0  0.0
# 3  NaN  Link  Chrome  welcome  Default  40.0  0.0
# 4  NaN  Link  Chrome  welcome  Default  27.0  0.0
#
#                                                    9     10
# 0  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12121
# 1  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12120
# 2  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12119
# 3  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12118
# 4  C:\Users\welcome\AppData\Local\Google\Chrome\U...  12117

# %%
other_df = pd.DataFrame({"TIME": other_df['Visit Time'], "TITLE": other_df['Title'], "URL": other_df['URL']})
other_df.head()
# Out:
#                  TIME                                              TITLE  \
# 0 2021-12-03 14:04:00  Oh! That Film Blog | The ramblings of a self c...
# 1 2021-12-03 14:04:00  The Movie Blog | The Official Home of Correct ...
# 2 2021-12-03 14:04:00  Movie-Blogger.com | The No.1 Independent Movie...
# 3 2021-12-03 14:04:00  Top 10 Movie Blogs on the Internet Today | Mov...
# 4 2021-12-03 14:04:00  The Film Blog | The official blog of everythin...
#
#                                      URL
# 0            https://ohthatfilmblog.com/
# 1          https://www.themovieblog.com/
# 2         https://www.movie-blogger.com/
# 3  https://blogging.org/top-movie-blogs/
# 4                  https://thefilm.blog/

# %%
other_df = other_df.sample(frac=1).reset_index(drop=True)

# %%
urls = list(other_df['URL'])
sample_fetched_words = []
page_embedding_list = []
for i, url in enumerate(tqdm(urls)):
    print(i)
    if i == 50:
        break
    _, fetched_words, _ = inference_tools.test_url(elmo, url)
    sample_fetched_words.append(fetched_words)
    emb = get_web_embedding(fetched_words)
    try:
        assert emb.shape == (50,1024) or emb.shape == (0,)
        page_embedding_list.append(emb)
    except Exception as e:
        print("Invalid embeddding shape", e, "at url", url)
# Out:
#   0%|                                                                                          | 0/216 [00:00<?, ?it/s]
# Processing Text from the web page
#   0%|                                                                                          | 0/216 [01:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29188/3498773512.py in <module>
#       5     if i == 50:
#       6         break
# ----> 7     _, fetched_words, _ = inference_tools.test_url(elmo, url)
#       8     sample_fetched_words.append(fetched_words)
#       9     emb = get_web_embedding(fetched_words)
#
# ~\OneDrive\Documents\GitHub\DIGITAL_DETOX_ASSISTANT\src\inference_tools.py in test_url(elmo, url)
#      50             all_words.extend(words)
#      51             for word in words:
# ---> 52                 if tools.is_rare(word):
#      53                     index = words.index(word)
#      54                     word_ind = find_word(fetched_rare_words, word)
#
# ~\OneDrive\Documents\GitHub\DIGITAL_DETOX_ASSISTANT\src\utils.py in is_rare(self, word)
#      69             emb = np.mean(word.embeddings, axis=0)
#      70             page_embedding.append(emb)
# ---> 71     page_embedding = np.array(page_embedding)
#      72     return page_embedding
#      73
#
# ~\OneDrive\Documents\GitHub\DIGITAL_DETOX_ASSISTANT\src\utils.py in lemmatize(self, text)
#      83             if index >= config.rare_word_threshold and self.lemmatize(word):
#      84                 return True
# ---> 85             else:
#      86                 return False
#      87         elif self.lemmatize(word) == '-PRON-':
#
# D:\Conda\envs\tf-cpu\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     443             if not hasattr(proc, "__call__"):
#     444                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 445             doc = proc(doc, **component_cfg.get(name, {}))
#     446             if doc is None:
#     447                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\resnet.py in predict(self, X)
#      16
#      17     def predict(self, X):
# ---> 18         Y = self._layers[0](X)
#      19         if isinstance(X, list) or isinstance(X, tuple):
#      20             return [X[i] + Y[i] for i in range(len(X))]
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\layernorm.py in predict(self, X)
#      52             return X
#      53         if self.child is not None:
# ---> 54             X = self.child.predict(X)
#      55         N, mu, var = _get_moments(self.ops, X)
#      56         Xh = _forward(self.ops, X, mu, var)
#
# D:\Conda\envs\tf-cpu\lib\site-packages\thinc\neural\_classes\maxout.py in predict(self, X__BI)
#      64     def predict(self, X__BI):
#      65         W = self.W.reshape((self.nO * self.nP, self.nI))
# ---> 66         X__BOP = self.ops.gemm(X__BI, W, trans2=True)
#      67         X__BOP += self.b.reshape((self.nO * self.nP,))
#      68         X__BOP = X__BOP.reshape((X__BOP.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
def get_web_embedding(f_words):
    page_embedding = []
    if len(f_words) > 50:
        f_words.sort(key=lambda x: x.count, reverse=True)
        for word in f_words[:50]:
            emb = np.mean(word.embeddings, axis=0)
            page_embedding.append(emb)
    page_embedding = np.array(page_embedding)
    return page_embedding
