# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import numpy as np
import pandas as pd
from transformers import BertTokenizer
import nltk
import string
import re
import sys
from bs4 import BeautifulSoup
import requests
import time
import spacy
from collections import Counter

# %%
options = Options()
options.add_argument('headless');
driver = webdriver.Chrome(executable_path=r'D:\Downloads\chromedriver_win32\chromedriver.exe', options = options)

# %%
skills = ['Deep Learning', 'Convolutional Neural Networks', 'TensorFlow', 'Machine Learning','Algorithms','Computer Vision','Deep Reinforcement Learning','Computer Science','Python','Matlab','Recurrent Neural Networks','Django','Java','Keras','PyTorch','Neural Networks','Edge Computing','OpenCV','Scikit-Learn','Natural Language Processing','Object Detection','Reinforcement Learning','Generative Adverserial Networks']
skills_df = pd.read_csv("../data/skills.csv")
skills_df = skills_df.drop(columns = ["Unnamed: 0"])
skills_df.head(25)
# Out:
#                              skills  \
# 0                     Deep Learning
# 1     Convolutional Neural Networks
# 2                        TensorFlow
# 3                  Machine Learning
# 4                        Algorithms
# 5                   Computer Vision
# 6       Deep Reinforcement Learning
# 7                  Computer Science
# 8                            Python
# 9                            Matlab
# 10        Recurrent Neural Networks
# 11                           Django
# 12                             Java
# 13                            Keras
# 14                          PyTorch
# 15                  Neural Networks
# 16                   Edge Computing
# 17                           OpenCV
# 18                     Scikit-Learn
# 19      Natural Language Processing
# 20                 Object Detection
# 21           Reinforcement Learning
# 22  Generative Adversarial Networks
#
#                                               summary
# 0   Deep learning  (also known as deep structured ...
# 1   In deep learning, a convolutional neural netwo...
# 2   TensorFlow is a free and open-source software ...
# 3   Machine learning (ML) is the study of computer...
# 4   In mathematics and computer science, an algori...
# 5   Computer vision is an interdisciplinary scient...
# 6   Deep reinforcement learning (deep RL) is a sub...
# 7   Computer science is the study of computation, ...
# 8                                                 NaN
# 9   MATLAB (an abbreviation of "MATrix LABoratory"...
# 10  A recurrent neural network (RNN) is a class of...
# 11                                                NaN
# 12  Java (Indonesian: Jawa, Indonesian pronunciati...
# 13  Keras is an open-source software library that ...
# 14  PyTorch is an open source machine learning lib...
# 15  A neural network is a network or circuit of ne...
# 16  Edge computing is a distributed computing para...
# 17  OpenCV (Open Source Computer Vision Library) i...
# 18  Scikit-learn (formerly scikits.learn and also ...
# 19  Natural language processing (NLP) is a subfiel...
# 20  Object detection is a computer technology rela...
# 21  Reinforcement learning (RL) is an area of mach...
# 22  A generative adversarial network (GAN) is a cl...

# %% [markdown]
# #### Using Bert Tokenizer

# %%
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
def bertTokens(text):
    bertTokens = bert_tokenizer.tokenize(text)
    return bertTokens
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 231508/231508 [00:00<00:00, 1284584.60B/s]

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

def lemmatization(texts):
    output = []
    for i in texts:
        s = [token.lemma_ for token in nlp(i)]
        output.append(' '.join(s))
    return output

def remove_punctuation(text):
    try:
        punctuationfree = "".join([i for i in text if i not in string.punctuation])
    except:
        return " "
    return punctuationfree

def lower_case(text):
    try:
        lower = text.lower()
    except:
        print("Lower Case failed?")
        return ""
    return lower

def tokenization(text):
    tokens = nltk.word_tokenize(text)
    return tokens

# %%
bert_vocab = list(bert_tokenizer.vocab.keys())
bert_vocab.append("-PRON-")
def rare_word_extractor(word_list):
    rare_words = {}
    for word in word_list:
        if word in bert_vocab:
            ind = bert_vocab.index(word)
            if ind > 2700:
                rare_words[word] = ind
        else:
            rare_words[word] = 0
    rare_words_list = list(rare_words.keys())
    return rare_words_list
skills_df['clean_summary'] = skills_df['summary'].apply(lambda x:remove_punctuation(x)) 
skills_df['clean_summary'] = skills_df['clean_summary'].apply(lambda x:lower_case(x)) 
skills_df['tokens'] = skills_df['clean_summary'].apply(lambda x:tokenization(x)) 
skills_df['lemma_tokens'] = skills_df['tokens'].apply(lambda x:lemmatization(x))
skills_df['rare_words'] = skills_df['lemma_tokens'].apply(lambda x:rare_word_extractor(x)) 
skills_df.head()
# Out:
#                           skills  \
# 0                  Deep Learning
# 1  Convolutional Neural Networks
# 2                     TensorFlow
# 3               Machine Learning
# 4                     Algorithms
#
#                                              summary  \
# 0  Deep learning  (also known as deep structured ...
# 1  In deep learning, a convolutional neural netwo...
# 2  TensorFlow is a free and open-source software ...
# 3  Machine learning (ML) is the study of computer...
# 4  In mathematics and computer science, an algori...
#
#                                        clean_summary  \
# 0  deep learning  also known as deep structured l...
# 1  in deep learning a convolutional neural networ...
# 2  tensorflow is a free and opensource software l...
# 3  machine learning ml is the study of computer a...
# 4  in mathematics and computer science an algorit...
#
#                                               tokens  \
# 0  [deep, learning, also, known, as, deep, struct...
# 1  [in, deep, learning, a, convolutional, neural,...
# 2  [tensorflow, is, a, free, and, opensource, sof...
# 3  [machine, learning, ml, is, the, study, of, co...
# 4  [in, mathematics, and, computer, science, an, ...
#
#                                         lemma_tokens  \
# 0  [deep, learn, also, know, as, deep, structure,...
# 1  [in, deep, learn, a, convolutional, neural, ne...
# 2  [tensorflow, be, a, free, and, opensource, sof...
# 3  [machine, learn, ml, be, the, study, of, compu...
# 4  [in, mathematic, and, computer, science, an, a...
#
#                                           rare_words
# 0  [deep, learn, structure, broad, machine, metho...
# 1  [deep, learn, convolutional, neural, network, ...
# 2  [tensorflow, opensource, software, library, ma...
# 3  [machine, learn, ml, study, computer, algorith...
# 4  [mathematic, computer, algorithm, listen, fini...

# %%
for index, row in skills_df.iterrows():
    print(row['rare_words'],"\n\n\n")
# Out:
# ['deep', 'learn', 'structure', 'broad', 'machine', 'method', 'base', 'artificial', 'neural', 'network', 'representation', 'supervise', 'semisupervised', 'unsuperviseddeeplearne', 'architecture', 'belief', 'reinforcement', 'recurrent', 'convolutional', 'apply', 'computer', 'vision', 'speech', 'recognition', 'natural', 'processing', 'translation', 'bioinformatics', 'drug', 'medical', 'image', 'analysis', 'material', 'inspection', '-PRON-', 'produce', 'result', 'comparable', 'surpass', 'expert', 'performanceartificial', 'anns', 'inspire', 'distribute', 'communication', 'node', 'biological', 'difference', 'brain', 'specifically', 'tend', 'static', 'symbolic', 'organism', 'dynamic', 'plastic', 'analoguethe', 'adjective', 'refer', 'multiple', 'layer', 'linear', 'perceptron', 'universal', 'classifier', 'nonpolynomial', 'activation', 'function', 'hide', 'unbounded', 'width', 'modern', 'variation', 'concerned', 'bound', 'size', 'permits', 'practical', 'application', 'optimize', 'implementation', 'retain', 'theoretical', 'universality', 'mild', 'condition', 'permit', 'heterogeneous', 'deviate', 'widely', 'biologically', 'inform', 'connectionist', 'model', 'sake', 'efficiency', 'trainability', 'understandability', 'whence']
#
#
#
# ['deep', 'learn', 'convolutional', 'neural', 'network', 'cnn', 'convnet', 'artificial', 'commonly', 'apply', 'analyze', 'visual', 'imagery', '-PRON-', 'shift', 'invariant', 'siann', 'base', 'sharedweight', 'architecture', 'convolution', 'kernel', 'filter', 'slide', 'input', 'feature', 'provide', 'translation', 'equivariant', 'response', 'map', 'counterintuitively', 'oppose', 'application', 'image', 'recognition', 'recommender', 'classification', 'segmentation', 'medical', 'analysis', 'natural', 'processing', 'braincomputer', 'interface', 'financial', 'seriescnns', 'regularize', 'multilayer', 'perceptron', 'usually', 'mean', 'fully', 'connect', 'neuron', 'layer', 'connectivity', 'prone', 'overfitting', 'datum', 'typical', 'ways', 'regularization', 'prevent', 'penalize', 'parameter', 'training', 'weight', 'decay', 'trim', 'skipped', 'connection', 'dropout', 'etc', 'cnns', 'approach', 'towards', 'advantage', 'hierarchical', 'pattern', 'assemble', 'increase', 'complexity', 'simple', 'emboss', 'therefore', 'scale', 'extreme', 'inspire', 'biological', 'process', 'resemble', 'organization', 'animal', 'cortex', 'individual', 'cortical', 'respond', 'stimuli', 'restrict', 'receptive', 'partially', 'overlap', 'cover', 'entire', 'relatively', 'preprocesse', 'compare', 'algorithms', 'learns', 'optimize', 'automate', 'whereas', 'traditional', 'handengineere', 'independence', 'prior', 'knowledge', 'intervention', 'extraction']
#
#
#
# ['tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'particular', 'focus', 'training', 'inference', 'deep', 'neural', 'networkstensorflow', 'develop', 'google', 'brain', 'internal', 'initial', 'release', 'apache', 'license', 'update', '2019tensorflow', 'wide', 'variety', 'programming', 'notably', 'python', 'javascript', 'java', 'flexibility', 'lend', 'application', 'sector']
#
#
#
# ['machine', 'learn', 'ml', 'study', 'computer', 'algorithms', 'improve', 'automatically', 'experience', 'datum', '-PRON-', 'artificial', 'intelligence', 'build', 'model', 'base', 'sample', 'training', 'prediction', 'decision', 'explicitly', 'wide', 'variety', 'application', 'medicine', 'email', 'filter', 'speech', 'recognition', 'vision', 'difficult', 'unfeasible', 'develop', 'conventional', 'perform', 'tasksa', 'subset', 'closely', 'relate', 'computational', 'statistic', 'focus', 'statistical', 'mathematical', 'optimization', 'deliver', 'method', 'theory', 'domain', 'mining', 'exploratory', 'analysis', 'unsupervise', 'implementation', 'neural', 'network', 'mimics', 'biological', 'brain', 'problem', 'refer', 'predictive', 'analytics']
#
#
#
# ['mathematic', 'computer', 'algorithm', 'listen', 'finite', 'sequence', 'welldefine', 'instruction', 'typically', 'solve', 'specific', 'problem', 'perform', 'computation', 'algorithms', 'specification', 'calculation', 'datum', 'processing', 'automate', 'reason', 'decisionmake', 'task', 'contrast', 'heuristic', 'approach', 'fully', 'specify', 'guarantee', 'correct', 'optimal', 'result', 'especially', 'domain', 'resultas', 'effective', 'method', 'express', 'amount', 'formal', 'calculate', 'function', 'start', 'initial', 'input', 'perhaps', 'empty', 'describe', 'execute', 'proceed', 'successive', 'eventually', 'produce', 'output', 'terminate', 'transition', 'necessarily', 'deterministic', 'randomize', 'incorporate', 'random']
#
#
#
# ['computer', 'vision', 'interdisciplinary', 'scientific', 'deal', 'gain', 'highlevel', 'understanding', 'digital', 'image', 'perspective', 'engineering', '-PRON-', 'seek', 'understand', 'automate', 'task', 'visual', 'docomputer', 'method', 'acquire', 'processing', 'analyze', 'extraction', 'highdimensional', 'datum', 'produce', 'numerical', 'symbolic', 'eg', 'decision', 'context', 'mean', 'transformation', 'input', 'retina', 'description', 'sense', 'process', 'elicit', 'appropriate', 'action', 'disentangling', 'model', 'construct', 'aid', 'geometry', 'physics', 'statistic', 'learn', 'theorythe', 'discipline', 'concerned', 'theory', 'artificial', 'extract', 'sequences', 'view', 'multiple', 'cameras', 'multidimensional', '3d', 'scanner', 'medical', 'scanning', 'device', 'technological', 'apply', 'construction', 'subdomains', 'scene', 'reconstruction', 'object', 'detection', 'event', 'tracking', 'recognition', 'pose', 'estimation', 'indexing', 'motion', 'servoe', 'restoration']
#
#
#
# ['deep', 'reinforcement', 'learn', 'rl', 'subfield', 'machine', 'combine', 'consider', 'problem', 'computational', 'agent', 'decision', 'trial', 'error', 'incorporates', 'solution', 'allow', 'unstructured', 'input', 'datum', 'manual', 'engineering', 'algorithms', 'eg', 'pixel', 'render', 'screen', 'decide', 'action', 'perform', 'optimize', 'objective', 'maximize', 'score', 'diverse', 'application', 'limited', 'robotic', 'natural', 'processing', 'computer', 'vision', 'transportation', 'finance', 'healthcare']
#
#
#
# ['computer', 'study', 'computation', 'automation', 'spans', 'theoretical', 'discipline', 'algorithms', 'theory', 'practical', 'implementation', 'hardware', 'software', 'generally', 'consider', 'academic', 'distinct', 'programming', 'datum', 'structure', 'concern', 'abstract', 'model', 'problem', 'solve', '-PRON-', 'cryptography', 'security', 'mean', 'secure', 'communication', 'prevent', 'vulnerability', 'graphic', 'computational', 'geometry', 'generation', 'image', 'approaches', 'description', 'process', 'database', 'management', 'repository', 'human – computer', 'interaction', 'investigates', 'interface', 'interact', 'engineering', 'focus', 'principle', 'develop', 'operate', 'network', 'embed', 'investigate', 'complex', 'architecture', 'describe', 'construction', 'component', 'computeroperate', 'equipment', 'artificial', 'intelligence', 'machine', 'learn', 'aim', 'synthesize', 'goalorientate', 'problemsolving', 'decisionmake', 'environmental', 'adaptation', 'planning', 'animal', 'vision', 'understand', 'natural', 'processing', 'textual', 'linguistic', 'fundamental', 'determine', 'automate', 'ture', 'recognize', 'distinction']
#
#
#
# []
#
#
#
# ['matlab', 'abbreviation', 'matrix', 'laboratory', 'proprietary', 'multiparadigm', 'programming', 'numeric', 'compute', 'environment', 'develop', 'mathworks', 'allow', 'manipulation', 'plot', 'function', 'datum', 'implementation', 'algorithms', 'creation', 'user', 'interface', 'write', 'intend', 'primarily', 'optional', 'toolbox', 'mupad', 'symbolic', 'engine', 'access', 'ability', 'additional', 'package', 'simulink', 'add', 'graphical', 'multidomain', 'simulation', 'modelbase', 'dynamic', 'embed', '2020', 'worldwide', 'background', 'engineering', 'economic']
#
#
#
# ['recurrent', 'neural', 'network', 'rnn', 'artificial', 'connection', 'node', 'direct', 'undirecte', 'graph', 'temporal', 'sequence', 'allow', '-PRON-', 'exhibit', 'dynamic', 'behavior', 'derive', 'feedforward', 'rnns', 'internal', 'memory', 'process', 'variable', 'length', 'sequences', 'input', 'applicable', 'task', 'unsegmented', 'connect', 'handwriting', 'recognition', 'speech', 'theoretically', 'ture', 'complete', 'arbitrary', 'inputsthe', 'term', 'refer', 'infinite', 'impulse', 'response', 'whereas', 'convolutional', 'finite', 'acyclic', 'unrolled', 'replace', 'strictly', 'cyclic', 'additional', 'store', 'storage', 'incorporates', 'delay', 'feedback', 'loop', 'gate', 'shortterm', 'lstms', 'unit', 'fnn', 'typical', 'library', 'pytorch', 'justintime', 'compilation', 'efficiently', 'implement']
#
#
#
# []
#
#
#
# ['java', 'indonesian', 'jawa', 'pronunciation', 'ˈdʒawa', 'javanese', 'ꦗꦮ', 'sundanese', 'ᮏᮝ', 'sunda', 'indonesia', '-PRON-', 'border', 'indian', 'ocean', 'sea', '1518', 'inhabitant', 'surround', 'principally', 'madura', 'constitutes', '561', 'percent', '1477', 'populous', 'islandindonesias', 'capital', 'jakarta', 'javas', 'northwestern', 'coast', 'wellknown', 'centre', 'powerful', 'hindubuddhist', 'empire', 'islamic', 'sultanate', 'core', 'colonial', 'dutch', 'indie', 'struggle', 'independence', '1930s', '1940s', 'dominate', 'politically', 'economically', 'culturally', 'indonesias', 'eight', 'unesco', 'heritage', 'locate', 'ujung', 'kulon', 'borobudur', 'temple', 'prambanan', 'sangiran', 'volcanic', 'eruption', 'geologic', 'subduction', 'australian', 'plate', '13th', 'fifth', 'landmass', '138800', 'kilometre', '53600', 'sq', 'mi', 'chain', 'mountain', 'east – west', 'spine', 'spoken', 'madurese', 'betawi', 'ethnic', 'native', 'island — the', 'eastern', 'salient', 'migrant', 'hybrid', 'resident', 'bilingual', 'speak', 'official', 'majority', 'muslim', 'comprise', 'diverse', 'religious', 'belief', 'ethnicity', 'culturesjava', 'divide', 'administrative', 'province', 'banten', 'yogyakarta']
#
#
#
# ['keras', 'opensource', 'software', 'library', 'provide', 'python', 'interface', 'artificial', 'neural', 'network', 'tensorflow', 'multiple', 'backend', 'microsoft', 'cognitive', 'toolkit', 'theano', 'plaidml', 'enable', 'fast', 'experimentation', 'deep', '-PRON-', 'focus', 'userfriendly', 'modular', 'extensible', 'develop', 'effort', 'oneiros', 'openende', 'neuroelectronic', 'intelligent', 'robot', 'operate', 'primary', 'author', 'maintainer', 'françois', 'chollet', 'google', 'engineer', 'xception', 'model']
#
#
#
# ['pytorch', 'source', 'machine', 'learn', 'library', 'base', 'torch', 'application', 'computer', 'vision', 'natural', 'processing', 'primarily', 'develop', 'facebooks', 'ai', 'lab', 'fair', '-PRON-', 'opensource', 'software', 'release', 'modify', 'bsd', 'license', 'python', 'interface', 'polished', 'primary', 'focus', 'interfacea', 'piece', 'deep', 'build', 'tesla', 'autopilot', 'uber', 'pyro', 'hug', 'transformer', 'lightning', 'catalystpytorch', 'provide', 'highlevel', 'feature', 'tensor', 'compute', 'numpy', 'strong', 'acceleration', 'via', 'graphic', 'unit', 'gpu', 'neural', 'network', 'typebase', 'automatic', 'differentiation']
#
#
#
# ['neural', 'network', 'circuit', 'neuron', 'modern', 'sense', 'artificial', 'compose', 'node', 'thus', 'biological', 'solve', 'intelligence', 'ai', 'problem', 'connection', 'model', 'weight', 'positive', 'reflect', 'excitatory', 'negative', 'value', 'mean', 'inhibitory', 'input', 'modify', 'sum', 'activity', 'refer', 'linear', 'combination', 'activation', 'function', 'amplitude', 'output', 'example', 'acceptable', 'range', 'usually', '-PRON-', '−1', 'predictive', 'adaptive', 'application', 'train', 'via', 'dataset', 'selflearne', 'result', 'experience', 'occur', 'derive', 'conclusion', 'complex', 'seemingly', 'unrelated']
#
#
#
# ['edge', 'compute', 'distribute', 'paradigm', 'bring', 'computation', 'datum', 'storage', 'source', 'expect', 'improve', 'response', 'save', 'bandwidth', 'misconception', 'iot', 'synonymous', 'topology', 'locationsensitive', 'instantiation', 'term', 'refer', 'architecture', 'rather', 'specific', 'technologythe', 'origin', 'lie', 'content', 'network', 'create', '1990s', 'serve', 'web', 'server', 'deploy', 'user', '2000s', 'evolve', 'host', 'application', 'component', 'result', 'commercial', 'hosted', 'dealer', 'locator', 'shopping', 'cart', 'realtime', 'aggregator', 'ad', 'insertion', 'engine']
#
#
#
# ['opencv', 'source', 'computer', 'vision', 'library', 'programming', 'function', 'mainly', 'aim', 'realtime', 'originally', 'develop', 'intel', '-PRON-', 'willow', 'garage', 'itseez', 'acquire', 'crossplatform', 'opensource', 'apache', 'license', 'start', 'feature', 'gpu', 'acceleration', 'operation']
#
#
#
# ['scikitlearn', 'formerly', 'scikitslearn', 'sklearn', 'software', 'machine', 'learn', 'library', 'python', 'programming', '-PRON-', 'feature', 'classification', 'regression', 'cluster', 'algorithms', 'vector', 'random', 'forest', 'gradient', 'boost', 'kmeans', 'dbscan', 'interoperate', 'numerical', 'scientific', 'numpy', 'scipy', 'numfocus', 'fiscally', 'sponsor']
#
#
#
# ['natural', 'processing', 'nlp', 'subfield', 'linguistic', 'computer', 'artificial', 'intelligence', 'concerned', 'interaction', 'particular', 'process', 'analyze', 'amount', 'datum', 'goal', 'capable', 'understanding', 'content', 'document', 'contextual', 'nuance', '-PRON-', 'technology', 'accurately', 'extract', 'insight', 'contain', 'categorize', 'organize', 'challenge', 'frequently', 'involve', 'speech', 'recognition', 'generation']
#
#
#
# ['object', 'detection', 'computer', 'technology', 'relate', 'vision', 'image', 'processing', 'deal', 'detect', 'instance', 'semantic', 'certain', 'digital', 'wellresearche', 'domain', 'pedestrian', 'application', 'retrieval', 'surveillance']
#
#
#
# ['reinforcement', 'learn', 'rl', 'machine', 'concerned', 'intelligent', 'agent', 'ought', 'action', 'environment', 'maximize', 'notion', 'cumulative', 'reward', 'basic', 'paradigms', 'alongside', 'supervise', 'unsupervise', 'differ', 'label', 'inputoutput', 'pairs', 'suboptimal', 'explicitly', 'correct', 'focus', 'balance', 'exploration', 'uncharted', 'territory', 'exploitation', 'current', 'knowledgepartially', 'algorithms', 'combine', 'advantage', 'typically', 'markov', 'decision', 'process', 'mdp', 'context', 'dynamic', 'programming', 'technique', 'difference', 'classical', 'method', 'latter', 'assume', 'knowledge', 'exact', 'mathematical', 'model', '-PRON-', 'target', 'mdps', 'infeasible']
#
#
#
# ['generative', 'adversarial', 'network', 'gan', 'machine', 'learn', 'frameworks', 'ian', 'goodfellow', '-PRON-', 'colleague', 'neural', 'contest', 'zerosum', 'agent', 'gain', 'loss', 'training', 'technique', 'learns', 'generate', 'datum', 'statistic', 'example', 'train', 'photograph', 'superficially', 'authentic', 'observer', 'realistic', 'characteristics', 'originally', 'propose', 'model', 'unsupervise', 'prove', 'useful', 'semisupervised', 'fully', 'supervise', 'reinforcement', 'learningthe', 'core', 'idea', 'base', 'indirect', 'discriminator', 'update', 'dynamically', 'basically', 'mean', 'generator', 'minimize', 'distance', 'specific', 'image', 'rather', 'fool', 'enable', 'manner']

# %%
history = pd.read_csv("../data/web_history/synthetic_490.csv")
history = history.drop(columns = ["Unnamed: 0"])
history
# Out:
#                                                    URL  \
# 0      https://www.tensorflow.org/tutorials/images/cnn
# 1                          https://www.tensorflow.org/
# 2             https://en.wikipedia.org/wiki/TensorFlow
# 3             https://github.com/tensorflow/tensorflow
# 4                          https://www.tensorflow.org/
# ..                                                 ...
# 486  https://en.wikipedia.org/w/index.php?search=Co...
# 487    https://en.wikipedia.org/wiki/Microsoft_Windows
# 488  https://en.wikipedia.org/wiki/Command-line_int...
# 489  https://en.wikipedia.org/wiki/Graphical_user_i...
# 490  https://en.wikipedia.org/wiki/Frontend_and_bac...
#
#                                                  TITLE         Visited_time
# 0    Convolutional Neural Network (CNN)  |  TensorF...  2021-12-03 03:39:00
# 1                                           TensorFlow  2021-12-03 03:39:00
# 2                               TensorFlow - Wikipedia  2021-12-03 03:38:00
# 3    tensorflow/tensorflow: An Open Source Machine ...  2021-12-03 03:38:00
# 4                                           TensorFlow  2021-12-03 03:38:00
# ..                                                 ...                  ...
# 486           Convolutional neural network - Wikipedia  2021-12-03 02:11:00
# 487                      Microsoft Windows - Wikipedia  2021-12-03 02:11:00
# 488                 Command-line interface - Wikipedia  2021-12-03 02:10:00
# 489               Graphical user interface - Wikipedia  2021-12-03 02:09:00
# 490                   Frontend and backend - Wikipedia  2021-12-03 02:08:00
#
# [491 rows x 3 columns]

# %%
work = []
for i in  range(0,491):
    work.append("WORK")
history['LABEL'] = pd.Series(work)
history.head()
# Out:
#                                                URL  \
# 0  https://www.tensorflow.org/tutorials/images/cnn
# 1                      https://www.tensorflow.org/
# 2         https://en.wikipedia.org/wiki/TensorFlow
# 3         https://github.com/tensorflow/tensorflow
# 4                      https://www.tensorflow.org/
#
#                                                TITLE         Visited_time  \
# 0  Convolutional Neural Network (CNN)  |  TensorF...  2021-12-03 03:39:00
# 1                                         TensorFlow  2021-12-03 03:39:00
# 2                             TensorFlow - Wikipedia  2021-12-03 03:38:00
# 3  tensorflow/tensorflow: An Open Source Machine ...  2021-12-03 03:38:00
# 4                                         TensorFlow  2021-12-03 03:38:00
#
#   LABEL
# 0  WORK
# 1  WORK
# 2  WORK
# 3  WORK
# 4  WORK

# %%
history['H1'] = np.empty((len(history), 0)).tolist()
history['H2'] = np.empty((len(history), 0)).tolist()
history['H3'] = np.empty((len(history), 0)).tolist()
history['H4'] = np.empty((len(history), 0)).tolist()
history['H5'] = np.empty((len(history), 0)).tolist()
history['H6'] = np.empty((len(history), 0)).tolist()
history['SPAN'] = np.empty((len(history), 0)).tolist()
history['p'] = np.empty((len(history), 0)).tolist()
history.head()
# Out:
#                                                URL  \
# 0  https://www.tensorflow.org/tutorials/images/cnn
# 1                      https://www.tensorflow.org/
# 2         https://en.wikipedia.org/wiki/TensorFlow
# 3         https://github.com/tensorflow/tensorflow
# 4                      https://www.tensorflow.org/
#
#                                                TITLE         Visited_time  \
# 0  Convolutional Neural Network (CNN)  |  TensorF...  2021-12-03 03:39:00
# 1                                         TensorFlow  2021-12-03 03:39:00
# 2                             TensorFlow - Wikipedia  2021-12-03 03:38:00
# 3  tensorflow/tensorflow: An Open Source Machine ...  2021-12-03 03:38:00
# 4                                         TensorFlow  2021-12-03 03:38:00
#
#   LABEL  H1  H2  H3  H4  H5  H6 SPAN   p
# 0  WORK  []  []  []  []  []  []   []  []
# 1  WORK  []  []  []  []  []  []   []  []
# 2  WORK  []  []  []  []  []  []   []  []
# 3  WORK  []  []  []  []  []  []   []  []
# 4  WORK  []  []  []  []  []  []   []  []

# %%
def process_url(url):
    driver.get(url)
    h1 = driver.find_elements_by_tag_name("h1")
    h2 = driver.find_elements_by_tag_name("h2")
    h3 = driver.find_elements_by_tag_name("h3")
    h4 = driver.find_elements_by_tag_name("h4")
    h5 = driver.find_elements_by_tag_name("h5")
    h6 = driver.find_elements_by_tag_name("h6")
    span = driver.find_elements_by_tag_name("span")
    p = driver.find_elements_by_tag_name("p")
    return (h1,h2,h3,h4,h5,h6,span,p)

def extract_rare_words_from_sel_objects(tag):
    rare_words = []
    if tag != None:
        for text in tag:
            rare_words.extend(rare_word_extractor(lemmatization(tokenization(lower_case(remove_punctuation(text.text))))))
    return rare_words

# %%
for index,row in history.iterrows():
    print("URL INDEX: ", index, "  LABEL: ", row['LABEL'] )
    if index >= 10:
        break
    
    if row['LABEL'] != "MISC":
        try:
            (h1,h2,h3,h4,h5,h6,span,p) = process_url(row['URL'])
        except:
            print("URL: ", row['URL'], "\n\n")
            print("Index:", index,"Exception while processing url")
            row['H1'] = []
            row['H2'] = []
            row['H3'] = []
            row['H4'] = []
            row['H5'] = []
            row['H6'] = []
            row['SPAN'] = []
            row['p'] = []
            continue
        time.sleep(1)

        try:
            rare_words_h1 = extract_rare_words_from_sel_objects(h1)
        except:
            print("Index:", index,"Exception while extracting h1")
            rare_words_h1 = []

        try:
            rare_words_h2 = extract_rare_words_from_sel_objects(h2)
        except:
            print("Index:", index,"Exception while extracting h2")
            rare_words_h2 = []

        try:
            rare_words_h3 = extract_rare_words_from_sel_objects(h3)
        except:
            print("Index:", index,"Exception while extracting h3")
            rare_words_h3 = []
        
        try:
            rare_words_h4 = extract_rare_words_from_sel_objects(h4)
        except:
            print("Index:", index,"Exception while extracting h4")
            rare_words_h4 = []
        
        try:
            rare_words_h5 = extract_rare_words_from_sel_objects(h5)
        except:
            print("Index:", index,"Exception while extracting h5")
            rare_words_h5 = []
        
        try:
            rare_words_h6 = extract_rare_words_from_sel_objects(h6)
        except:
            print("Index:", index,"Exception while extracting h6")
            rare_words_h6 = []
        
        try:
            rare_words_span = extract_rare_words_from_sel_objects(span)
        except:
            print("Index:", index,"Exception while extracting span")
            rare_words_span = []
        

        try:
            rare_words_p  = extract_rare_words_from_sel_objects(p)
        except:      
            print("Index:", index,"Exception while extracting p")
            rare_words_p = []
        
        print("URL: ", row['URL'], "\n\n")
        print("H1:  ",rare_words_h1, str("\n"))
        print("H2:  ",rare_words_h2,str("\n"))
        print("H3:  ",rare_words_h3,str("\n"))
        print("H4:  ",rare_words_h4, str("\n"))
        print("H5:  ",rare_words_h5,str("\n"))
        print("H6:  ",rare_words_h6,str("\n"))
        print("SPAN:  ",rare_words_span,str("\n"))
        print("P:  ",rare_words_p,str("\n"))
    else:
        rare_words_h1 = []
        rare_words_h2 = []
        rare_words_h3 = []
        rare_words_h4 = []
        rare_words_h5 = []
        rare_words_h6 = []
        rare_words_span = []
        rare_words_p = []    
    
    row['H1'] = rare_words_h1
    row['H2'] = rare_words_h2
    row['H3'] = rare_words_h3
    row['H4'] = rare_words_h4
    row['H5'] = rare_words_h5
    row['H6'] = rare_words_h6
    row['SPAN'] = rare_words_span
    row['p'] = np.array(rare_words_p)
# Out:
# URL INDEX:  0   LABEL:  WORK
# URL:  https://www.tensorflow.org/tutorials/images/cnn
#
#
# H1:   ['convolutional', 'neural', 'network', 'cnn']
#
# H2:   []
#
# H3:   ['import', 'tensorflow', 'download', 'prepare', 'cifar10', 'dataset', 'verify', 'datum', 'create', 'convolutional', 'base', 'add', 'dense', 'layer', 'compile', 'train', 'model', 'evaluate', 'model', 'stay', 'connect']
#
# H4:   []
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['page', 'page', 'import', 'tensorflow', 'download', 'prepare', 'cifar10', 'dataset', 'verify', 'datum', 'create', 'convolutional', 'base', 'add', 'dense', 'layer', 'compile', 'train', 'model', 'evaluate', 'model', 'import', 'tensorflow', 'tf', 'tensorflow', 'keras', 'import', 'dataset', 'layer', 'model', 'import', 'matplotlib', 'pyplot', 'plt', 'trainimage', 'trainlabel', 'testimage', 'testlabel', 'dataset', 'cifar10', 'loaddata', 'normalize', 'pixel', 'value', 'trainimage', 'testimage', 'trainimage', '2550', 'testimage', '2550', 'classname', 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck', 'plt', 'figure', 'figsize', 'range', 'plt', 'subplot', 'plt', 'xticks', 'plt', 'ytick', 'plt', 'grid', 'false', 'plt', 'imshow', 'trainimage', 'cifar', 'label', 'happen', 'arrays', '-PRON-', 'extra', 'index', 'plt', 'xlabel', 'classname', 'trainlabel', 'plt', 'model', 'model', 'sequential', 'model', 'add', 'layer', 'conv2d', '32', 'activation', 'relu', 'inputshape', '32', '32', 'model', 'add', 'layer', 'maxpooling2d', 'model', 'add', 'layer', 'conv2d', '64', 'activation', 'relu', 'model', 'add', 'layer', 'maxpooling2d', 'model', 'add', 'layer', 'conv2d', '64', 'activation', 'relu', 'model', 'summary', 'model', 'add', 'layer', 'flatten', 'model', 'add', 'layer', 'dense', '64', 'activation', 'relu', 'model', 'add', 'layer', 'dense', 'model', 'summary', 'model', 'compile', 'optimizer', 'adam', 'loss', 'tf', 'keras', 'loss', 'sparsecategoricalcrossentropy', 'fromlogits', 'true', 'metric', 'accuracy', 'model', 'fit', 'trainimage', 'trainlabel', 'epoch', 'validationdata', 'testimage', 'testlabel', 'plt', 'plot', 'accuracy', 'label', 'accuracy', 'plt', 'plot', 'valaccuracy', 'label', 'valaccuracy', 'plt', 'xlabel', 'epoch', 'plt', 'ylabel', 'accuracy', 'plt', 'ylim', '05', 'plt', 'legend', 'loc', 'testloss', 'testacc', 'model', 'evaluate', 'testimage', 'testlabel', 'verbose', 'print', 'testacc', 'sign', 'tensorflow', 'monthly', 'newsletter']
#
# P:   ['tutorial', 'demonstrate', 'training', 'simple', 'convolutional', 'neural', 'network', 'cnn', 'classify', 'cifar', 'image', 'keras', 'sequential', 'api', 'create', '-PRON-', 'model', 'code', 'cifar10', 'dataset', 'contain', '60000', 'color', 'image', '6000', 'divide', '50000', 'training', '10000', 'testing', 'mutually', 'exclusive', 'overlap', '-PRON-', 'verify', 'dataset', 'correct', 'lets', 'plot', 'image', 'training', 'display', 'below', 'code', 'below', 'define', 'convolutional', 'base', 'pattern', 'stack', 'conv2d', 'maxpooling2d', 'layer', 'input', 'cnn', 'tensor', 'shape', 'imageheight', 'imagewidth', 'colorchannel', 'ignore', 'batch', 'size', '-PRON-', 'dimension', 'refer', 'rgb', 'example', 'configure', 'process', '32', 'format', 'cifar', 'image', 'pass', 'argument', 'inputshape', 'layer', 'lets', 'display', 'architecture', '-PRON-', 'model', '-PRON-', 'output', 'conv2d', 'maxpooling2d', 'layer', '3d', 'tensor', 'shape', 'height', 'width', 'channel', 'dimension', 'tend', 'shrink', 'deeply', 'network', 'argument', 'eg', '32', '64', 'typically', 'afford', 'computationally', 'add', 'complete', 'model', '-PRON-', 'feed', 'output', 'tensor', 'convolutional', 'base', 'shape', '64', 'dense', 'layer', 'perform', 'classification', 'vector', 'input', '1d', 'current', '3d', 'flatten', 'unroll', 'add', 'cifar', 'complete', 'architecture', '-PRON-', 'model', 'network', 'summary', '64', 'output', 'flatten', 'vector', 'shape', '1024', 'dense', 'layer', '-PRON-', 'simple', 'cnn', 'achieve', 'test', 'accuracy', '70', 'bad', 'code', 'style', 'check', 'tensorflow', 'quickstart', 'expert', 'example', 'keras', 'subclasse', 'api', 'tfgradienttape', 'except', 'otherwise', 'note', 'content', 'page', 'license', 'creative', 'commons', 'attribution', '40', 'code', 'sample', 'apache', 'detail', 'google', 'developer', 'policy', 'java', 'register', 'trademark', 'oracle', 'andor', '-PRON-', 'affiliate', 'update', '20211111', 'utc']
#
# URL INDEX:  1   LABEL:  WORK
# URL:  https://www.tensorflow.org/
#
#
# H1:   []
#
# H2:   ['tensorflow', 'solution', 'ml', 'problem', 'tensorflow', 'tensorflow', 'news', 'announcement', 'resource', 'build', 'deploy', 'experiment', 'easily', 'tensorflow']
#
# H3:   ['sign', 'tensorflow', 'monthly', 'newsletter', 'stay', 'connect']
#
# H4:   ['easy', 'model', 'build', 'robust', 'ml', 'anywhere', 'powerful', 'experimentation']
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['airbnb', 'coca', 'cola', 'deepmind', 'ge', 'healthcare', 'google', 'intel', 'nersc', 'twitter', 'sign', 'tensorflow', 'monthly', 'newsletter']
#
# P:   ['tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'resource', 'lets', 'researcher', 'push', 'stateoftheart', 'ml', 'developer', 'easily', 'build', 'deploy', 'application', 'build', 'train', 'ml', 'model', 'easily', 'intuitive', 'highlevel', 'apis', 'keras', 'eager', 'execution', 'immediate', 'iteration', 'easy', 'debug', 'easily', 'train', 'deploy', 'model', 'cloud', 'onprem', 'browser', 'ondevice', 'matter', '-PRON-', 'simple', 'flexible', 'architecture', 'idea', 'concept', 'code', 'stateoftheart', 'model', 'publication', 'fast', 'simple', 'stepbystep', 'walkthrough', 'solve', 'ml', 'problem', 'tensorflow', 'train', 'neural', 'network', 'classify', 'image', 'clothing', 'sneaker', 'shirt', 'fastpace', 'overview', 'complete', 'tensorflow', 'start', 'build', 'training', 'retrieval', 'model', 'predict', 'movie', 'user', 'likely', 'watch', 'rank', 'create', 'recommendation', 'train', 'generative', 'adversarial', 'network', 'generate', 'image', 'handwritten', 'digits', 'keras', 'subclasse', 'api', 'diverse', 'developer', 'enterprise', 'researcher', 'ml', 'solve', 'challenge', 'realworld', 'problem', 'learn', '-PRON-', 'application', 'poweredbytf', 'share', 'check', 'tensorflow', 'blog', 'additional', 'updates', 'subscribe', '-PRON-', 'monthly', 'newsletter', 'announcement', 'send', 'directly', 'inbox', 'explore', 'google', 'machine', 'learn', 'ecosystem', 'apply', '-PRON-', 'mlpowere', 'apps', 'cut', 'edge', 'dev', 'library', 'showcase', 'developer', 'create', 'google', 'technology', 'build', 'ml', 'submit', '-PRON-', 'discover', 'solution', '-PRON-', 'integrate', 'machine', 'learn', 'mobile', 'web', 'apps', 'google', 'developer', 'pathway', 'guide', 'ml', 'scenario', 'custom', 'explore', '-PRON-', 'discussion', 'platform', 'share', 'idea', 'answer', 'technical', 'question', 'learn', 'tensorflow', 'create', 'account', 'join', 'conversation', '-PRON-', 'committed', 'foster', 'welcome', 'ml', 'join', 'tensorflow', 'grow', 'ecosystem', 'join', 'tensorflow', 'forum', 'share', 'idea', 'discuss', 'technical', 'question', 'connect', '-PRON-', 'regularly', 'tensorflow', 'blog', 'content', 'article', '-PRON-', 'youtube', 'channel', 'focus', 'machine', 'learn', 'ai', 'tensorflow', 'explore', 'meet', 'ask', 'code', 'uptodate', 'news', 'updates', 'tensorflow', 'follow', 'twitter', 'join', 'tensorflow', 'announcement', 'mail', 'list', 'learn', 'release', 'updates', 'security', 'advisory']
#
# URL INDEX:  2   LABEL:  WORK
# URL:  https://en.wikipedia.org/wiki/TensorFlow
#
#
# H1:   ['tensorflow']
#
# H2:   ['content', 'historyedit', 'featuresedit', 'usage', 'extensionsedit', 'applicationsedit', 'alsoedit', 'bibliographyedit', 'external', 'linksedit', 'referencesedit']
#
# H3:   ['distbeliefedit', 'tensorflowedit', 'tensor', 'processing', 'unit', 'tpuedit', 'edge', 'tpuedit', 'tensorflow', 'liteedit', 'pixel', 'visual', 'core', 'pvcedit', 'tensorflow', '20edit', 'autodifferentiationedit', 'eager', 'executionedit', 'distributeedit', 'lossesedit', 'metricsedit', 'tfnnedit', 'optimizersedit', 'tensorflowedit', 'tensorflowjsedit', 'tfliteedit', 'tfxedit', 'integrationsedit', 'extensionsedit', 'medicaledit', 'mediaedit', 'search', 'engineedit', 'educationedit', 'retailedit', 'researchedit', 'search', 'contribute', 'tool', 'printexport']
#
# H4:   ['numpyedit', 'google', 'colabedit']
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['-PRON-', 'reader', '-PRON-', 'sunday', '1st', 'sunday', 'problem', 'donate', 'ways', 'frequently', 'ask', 'question', '-PRON-', 'sell', 'submit', 'agree', 'donor', 'privacy', 'policy', 'wikimedia', 'foundation', 'nonprofit', 'taxexempt', 'organization', 'recur', 'donation', 'debited', 'notify', 'send', 'email', 'link', 'easy', 'cancellation', 'instruction', '-PRON-', 'sell', 'submit', 'agree', 'donor', 'privacy', 'policy', 'wikimedia', 'foundation', 'nonprofit', 'taxexempt', 'organization', '-PRON-', 'recur', 'donation', 'debited', 'wikimedia', 'foundation', 'notify', 'send', 'email', 'link', 'easy', 'cancellation', 'instruction', 'select', 'amount', 'usd', 'usd', 'average', 'donation', '1636', 'average', 'donation', '1636', 'continue', 'ago', 'ago', 'month', 'ago', 'githubcomtensorflowtensorflow', 'wwwtensorfloworg', 'distbelief', 'tensorflow', 'tensor', 'processing', 'unit', 'tpu', 'edge', 'tpu', 'tensorflow', 'lite', 'pixel', 'visual', 'core', 'pvc', 'tensorflow', 'feature', 'autodifferentiation', 'eager', 'execution', 'distribute', 'loss', 'metric', 'tfnn', 'optimizer', 'usage', 'extension', '31', 'tensorflow', '32', 'tensorflowjs', '33', 'tflite', '34', 'tfx', '35', 'integration', '351', 'numpy', '36', 'extension', '361', 'google', 'colab', 'application', '41', 'medical', '42', 'medium', '43', 'search', 'engine', '44', '45', 'retail', '46', 'bibliography', 'external', 'link', 'reference', 'edit', 'distbelief', 'edit', 'tensorflow', 'edit', 'tensor', 'processing', 'unit', 'tpu', 'edit', 'edge', 'tpu', 'edit', 'tensorflow', 'lite', 'edit', 'pixel', 'visual', 'core', 'pvc', 'edit', 'tensorflow', 'edit', 'nonprimary', 'source', 'feature', 'edit', 'autodifferentiation', 'edit', 'eager', 'execution', 'edit', 'distribute', 'edit', 'loss', 'edit', 'metric', 'edit', 'tfnn', 'edit', 'optimizer', 'edit', 'usage', 'extension', 'edit', 'tensorflow', 'edit', 'tensorflowjs', 'edit', 'tflite', 'edit', 'tfx', 'edit', 'integration', 'edit', 'numpy', 'edit', 'extension', 'edit', 'google', 'colab', 'edit', 'application', 'edit', 'medical', 'edit', 'medium', 'edit', 'search', 'engine', 'edit', 'edit', 'retail', 'edit', 'edit', 'edit', 'opensource', 'software', 'portal', 'bibliography', 'edit', 'external', 'link', 'edit', 'official', 'website', 'official', 'website', 'reference', 'edit', 'credit', 'tensorfloworg', 'retrieve', 'retrieve', 'release', 'tensorflow', '261', 'tensorflowtensorflow', 'github', '2021', 'retrieve', 'retrieve', '2021', 'tensorflowjs', 'retrieve', '2018', 'retrieve', '2018', 'abadi', 'martín', 'barham', 'paul', 'chen', 'jianmin', 'zhifeng', 'davis', 'andy', 'dean', 'jeffrey', 'devin', 'matthieu', 'ghemawat', 'sanjay', 'irving', 'geoffrey', 'isard', 'michael', 'kudlur', 'manjunath', 'levenberg', 'josh', 'monga', 'rajat', 'moore', 'sherry', 'murray', 'derek', 'steiner', 'benoit', 'tucker', 'vasudevan', 'vijay', 'warden', 'pete', 'wicke', 'martin', 'yu', 'yuan', 'zheng', 'xiaoqiang', 'tensorflow', 'largescale', 'machine', 'learn', 'pdf', 'arxiv160508695', 'pdf', '160508695', 'cite', 'videourlhttpswwwyoutubecomwatchvozikw5k2fm7c', 'archiveurlhttpsghostarchiveorgvarchiveyoutube20211111ozikw5k2fm7c', 'archivedate20211111', 'urlstatuslivetitletensorflow', 'source', 'machine', 'learningyear', '2015authorgooglerefciterefvideoclipbygoogleabouttensorflow2015', '-PRON-', 'learn', 'software', 'kind', 'perceptual', 'understanding', 'task', 'jeffrey', 'dean', 'minute', '047', '217', 'youtube', 'clip', 'clip', 'google', 'tensorflow', 'minute', '015217', 'clip', 'google', 'tensorflow', 'minute', '026217', 'dean', 'et', 'metz', 'cade', 'google', 'source', 'tensorflow', '-PRON-', 'artificial', 'intelligence', 'engine', 'wire', 'retrieve', 'retrieve', 'tensorflow', '2019', 'available', 'medium', 'retrieve', 'retrieve', '2019', 'api', 'documentation', 'retrieve', '2018', 'retrieve', '2018', 'dean', 'jeff', 'monga', 'rajat', 'et', 'tensorflow', 'largescale', 'machine', 'learn', 'heterogeneous', 'pdf', 'tensorfloworg', 'google', 'retr ...
#
# P:   ['tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'particular', 'focus', 'training', 'inference', 'deep', 'neural', 'networks45', 'tensorflow', 'develop', 'google', 'brain', 'internal', 'production678', 'initial', 'release', 'apache', 'license', '201519', 'update', '201910', 'tensorflow', 'wide', 'variety', 'programming', 'notably', 'python', 'javascript', 'java11', 'flexibility', 'lend', '-PRON-', 'range', 'application', 'sector', 'start', 'google', 'brain', 'build', 'distbelief', 'proprietary', 'machine', 'learn', 'base', 'deep', 'neural', 'network', '-PRON-', 'grow', 'rapidly', 'diverse', 'alphabet', 'commercial', 'applications1213', 'assign', 'multiple', 'computer', 'scientist', 'jeff', 'dean', 'simplify', 'refactor', 'codebase', 'fast', 'robust', 'applicationgrade', 'library', 'tensorflow14', 'geoffrey', 'hinton', 'implement', 'generalize', 'backpropagation', 'improvement', 'allow', 'generation', 'substantially', 'accuracy', 'instance', 'reduction', 'error', 'speech', 'recognition15', 'tensorflow', 'google', 'brain', 'secondgeneration', 'release', '201716', 'reference', 'implementation', 'device', 'multiple', 'cpus', 'gpus', 'optional', 'cuda', 'sycl', 'extension', 'generalpurpose', 'compute', 'graphic', 'processing', 'units17', 'available', '64bit', 'linux', 'macos', 'windows', 'mobile', 'platform', 'android', 'ios', '-PRON-', 'flexible', 'architecture', 'allow', 'easy', 'deployment', 'computation', 'variety', 'platform', 'cpus', 'gpus', 'tpus', 'desktop', 'cluster', 'server', 'mobile', 'edge', 'device', 'tensorflow', 'computation', 'express', 'stateful', 'dataflow', 'graphs', 'derive', 'operation', 'neural', 'network', 'perform', 'multidimensional', 'datum', 'arrays', 'refer', 'tensor', 'google', 'io', 'conference', 'jeff', 'dean', '1500', 'repository', 'github', 'mention', 'google18', 'developer', 'google', 'cisco', 'redhat', 'coreos', 'caicloud', 'introduce', 'kubeflow', 'conference', 'allow', 'operation', 'deployment', 'tensorflow', 'kubernetes', '2018', 'google', 'announce', 'tensorflowjs', 'machine', 'learn', 'javascript19', 'jan', '2019', 'google', 'announce', 'tensorflow', '2020', '-PRON-', 'officially', 'available', 'sep', '201910', '2019', 'google', 'announce', 'tensorflow', 'graphic', 'deep', 'learn', 'computer', 'graphics21', 'google', 'announce', '-PRON-', 'tensor', 'processing', 'unit', 'tpu', 'applicationspecific', 'integrate', 'circuit', 'asic', 'hardware', 'chip', 'build', 'specifically', 'machine', 'learn', 'tailor', 'tensorflow', 'programmable', 'ai', 'accelerator', 'provide', 'throughput', 'lowprecision', 'arithmetic', 'eg', '8bit', 'orient', 'model', 'rather', 'training', 'tpus', 'datum', 'deliver', 'magnitude', 'betteroptimize', 'performance', 'watt', 'learning22', 'google', 'announce', 'secondgeneration', 'availability', 'tpus', 'compute', 'engine23', 'deliver', '180', 'teraflops', 'performance', 'organize', 'cluster', '64', 'provide', '115', 'petaflop', '2018', 'google', 'announce', 'thirdgeneration', 'tpus', 'deliver', '420', 'teraflops', 'performance', '128', 'gb', 'bandwidth', 'memory', 'hbm', 'cloud', 'tpu', 'v3', 'pod', 'offer', 'petaflop', '32', 'tb', 'hbm24', '2018', 'google', 'announce', '-PRON-', 'tpus', 'available', 'beta', 'cloud', 'platform25', '2018', 'edge', 'tpu', 'announce', 'googles', 'purposebuilt', 'asic', 'chip', 'tensorflow', 'lite', 'machine', 'learn', 'ml', 'model', 'client', 'compute', 'device', 'smartphones26', 'google', 'announce', 'software', 'stack', 'specifically', 'mobile', 'tensorflow', 'lite27', '2019', 'release', 'developer', 'preview', 'gpu', 'inference', 'engine', 'opengl', 'es', '31', 'compute', 'shader', 'android', 'device', 'metal', 'ios', 'devices28', '-PRON-', 'lite', 'micro', 'microcontroller', 'arm', 'utensor', 'merging29', 'google', 'release', 'pixel', 'feature', '-PRON-', 'visual', 'core', 'pvc', 'fully', 'programmable', 'image', 'vision', 'ai', 'processor', 'mobile', 'de ...
#
# URL INDEX:  3   LABEL:  WORK
# URL:  https://github.com/tensorflow/tensorflow
#
#
# H1:   ['tensorflow']
#
# H2:   ['commit', 'git', 'stat', 'file', 'readmemd', 'install', 'contribution', 'guideline', 'continuous', 'build', 'status', 'resource', 'license', 'release', '152', 'package', '167k', 'contributor', '3032']
#
# H3:   ['official', 'builds', 'topic', 'resource', 'license', 'code', 'conduct', 'citation']
#
# H4:   ['try', '-PRON-', 'tensorflow']
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['tensorflow', 'star', 'code', 'issue', '26k', 'pull', 'request', '168', 'action', 'master', 'code', 'update', 'generate', 'wrapper', 'function', 'tensorflow', 'ops', '122146', 'github', 'ci', 'python', '39', 'pylint', 'presubmit', 'action', 'tensorflow', 'update', 'generate', 'wrapper', 'function', 'tensorflow', 'ops', 'thirdparty', 'update', 'tfrt', 'dependency', 'revision', 'tool', 'merge', 'pull', 'request', '25673', 'ryanqiyujiangenvcapturescriptmor …', 'bazelrc', 'add', 'bazel', 'config', 'option', 'manylinux2014', 'bazelversion', 'upgrade', 'bazel', '421', 'gitignore', 'ignore', 'coreml', 'build', 'file', 'generate', 'configure', 'script', 'pylintrc', 'add', 'softlink', 'pylintrc', 'root', 'zenodojson', 'add', 'zenodojson', 'clean', 'automate', 'doi', 'author', 'format', 'author', 'file', '14881', 'build', 'nfc', 'internal', 'polish', 'copybara', 'workflow', 'file', 'citationcff', 'add', 'citationcff', 'codeowner', 'replace', 'kkimdev', 'saxenasaurabh', 'codeofconductmd', 'update', 'codeofconduct', 'fix', 'break', 'sync', 'contributingmd', 'merge', 'pull', 'request', '52546', 'bhackpatch19', 'issuesmd', 'internal', 'issuetemplatemd', 'merge', 'pull', 'request', '40033', 'abdulbaseermohammedkhanmaster', 'license', 'remove', 'duplicate', 'license', 'thirdparty', 'dependency', 'and …', 'readmemd', 'remove', 'extra', 'releasemd', 'update', 'tf2', 'mid', 'api', 'embed', 'op', 'securitymd', 'update', 'security', 'advisory', 'workspace', 'prevent', 'buildifier', 'warning', 'workspace', 'file', 'armcompilerbuild', 'update', 'compilerpiece', 'rpi', 'arm', 'compiler', 'configure', 'perfer', 'python3', 'compile', 'configurecmd', 'update', 'configurecmd', 'configurepy', 'upgrade', 'bazel', '421', 'modelsbuild', 'modelsbuild', 'filegroup', 'metadata', 'file', 'and …', 'import', 'tensorflow', 'tf', 'tf', 'add', 'numpy', 'hello', 'tf', 'constant', 'hello', 'tensorflow', 'hello', 'numpy', 'bhello', 'tensorflow', 'tensorfloworg', '152', 'tensorflow', '262', '167k', '166800', '3032', '627', 'python', '242', 'mlir', '40', 'starlark', 'html']
#
# P:   ['tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'resource', 'lets', 'researcher', 'push', 'stateoftheart', 'ml', 'developer', 'easily', 'build', 'deploy', 'mlpowere', 'application', 'tensorflow', 'originally', 'develop', 'researcher', 'engineer', 'google', 'brain', 'googles', 'machine', 'intelligence', 'organization', 'conduct', 'learn', 'deep', 'neural', 'network', 'applicable', 'wide', 'variety', 'domain', 'tensorflow', 'provide', 'stable', 'python', 'apis', 'nonguarantee', 'backward', 'compatible', 'api', 'uptodate', 'release', 'announcement', 'security', 'updates', 'subscribe', 'announcetensorfloworg', 'mail', 'list', 'tensorflow', 'install', 'guide', 'pip', 'package', 'enable', 'gpu', 'docker', 'container', 'build', 'source', 'install', 'current', 'release', 'cudaenable', 'gpu', 'card', 'ubuntu', 'windows', 'cpuonly', 'package', 'available', 'update', 'tensorflow', 'add', 'upgrade', 'flag', 'command', 'nightly', 'binary', 'available', 'testing', 'tfnightly', 'tfnightlycpu', 'package', 'pypi', 'example', 'tensorflow', 'tutorial', '-PRON-', 'contribute', 'tensorflow', 'review', 'contribution', 'guideline', 'adhere', 'code', 'conduct', 'participate', 'expect', 'uphold', '-PRON-', 'github', 'issue', 'tracking', 'request', 'bug', 'please', 'tensorflow', 'discuss', 'question', 'discussion', 'direct', 'specific', 'stack', 'overflow', 'tensorflow', 'strive', 'abide', 'generally', 'accept', 'practice', 'opensource', 'software', '-PRON-', 'communitysupporte', 'platform', 'configuration', 'tensorflow', 'sig', 'build', 'builds', 'table', 'learn', 'tensorflow', 'contribute', 'apache', 'license', 'source', 'machine', 'learn', 'framework', 'everyone']
#
# URL INDEX:  4   LABEL:  WORK
# URL:  https://www.tensorflow.org/
#
#
# H1:   []
#
# H2:   ['tensorflow', 'solution', 'ml', 'problem', 'tensorflow', 'tensorflow', 'news', 'announcement', 'resource', 'build', 'deploy', 'experiment', 'easily', 'tensorflow']
#
# H3:   ['sign', 'tensorflow', 'monthly', 'newsletter', 'stay', 'connect']
#
# H4:   ['easy', 'model', 'build', 'robust', 'ml', 'anywhere', 'powerful', 'experimentation']
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['airbnb', 'coca', 'cola', 'deepmind', 'ge', 'healthcare', 'google', 'intel', 'nersc', 'twitter', 'sign', 'tensorflow', 'monthly', 'newsletter']
#
# P:   ['tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'resource', 'lets', 'researcher', 'push', 'stateoftheart', 'ml', 'developer', 'easily', 'build', 'deploy', 'application', 'build', 'train', 'ml', 'model', 'easily', 'intuitive', 'highlevel', 'apis', 'keras', 'eager', 'execution', 'immediate', 'iteration', 'easy', 'debug', 'easily', 'train', 'deploy', 'model', 'cloud', 'onprem', 'browser', 'ondevice', 'matter', '-PRON-', 'simple', 'flexible', 'architecture', 'idea', 'concept', 'code', 'stateoftheart', 'model', 'publication', 'fast', 'simple', 'stepbystep', 'walkthrough', 'solve', 'ml', 'problem', 'tensorflow', 'train', 'neural', 'network', 'classify', 'image', 'clothing', 'sneaker', 'shirt', 'fastpace', 'overview', 'complete', 'tensorflow', 'start', 'build', 'training', 'retrieval', 'model', 'predict', 'movie', 'user', 'likely', 'watch', 'rank', 'create', 'recommendation', 'train', 'generative', 'adversarial', 'network', 'generate', 'image', 'handwritten', 'digits', 'keras', 'subclasse', 'api', 'diverse', 'developer', 'enterprise', 'researcher', 'ml', 'solve', 'challenge', 'realworld', 'problem', 'learn', '-PRON-', 'application', 'poweredbytf', 'share', 'check', 'tensorflow', 'blog', 'additional', 'updates', 'subscribe', '-PRON-', 'monthly', 'newsletter', 'announcement', 'send', 'directly', 'inbox', 'explore', 'google', 'machine', 'learn', 'ecosystem', 'apply', '-PRON-', 'mlpowere', 'apps', 'cut', 'edge', 'dev', 'library', 'showcase', 'developer', 'create', 'google', 'technology', 'build', 'ml', 'submit', '-PRON-', 'discover', 'solution', '-PRON-', 'integrate', 'machine', 'learn', 'mobile', 'web', 'apps', 'google', 'developer', 'pathway', 'guide', 'ml', 'scenario', 'custom', 'explore', '-PRON-', 'discussion', 'platform', 'share', 'idea', 'answer', 'technical', 'question', 'learn', 'tensorflow', 'create', 'account', 'join', 'conversation', '-PRON-', 'committed', 'foster', 'welcome', 'ml', 'join', 'tensorflow', 'grow', 'ecosystem', 'join', 'tensorflow', 'forum', 'share', 'idea', 'discuss', 'technical', 'question', 'connect', '-PRON-', 'regularly', 'tensorflow', 'blog', 'content', 'article', '-PRON-', 'youtube', 'channel', 'focus', 'machine', 'learn', 'ai', 'tensorflow', 'explore', 'meet', 'ask', 'code', 'uptodate', 'news', 'updates', 'tensorflow', 'follow', 'twitter', 'join', 'tensorflow', 'announcement', 'mail', 'list', 'learn', 'release', 'updates', 'security', 'advisory']
#
# URL INDEX:  5   LABEL:  WORK
# URL:  https://www.google.com/search?q=tensorflow&sxsrf=AOaemvJ8jbtZUJNPMoLhigUIZ59MRlAoQw%3A1638520683572&ei=a9epYYCyIoulptQPxayFcA&oq=tensor+flow&gs_lcp=&sclient=gws-wiz
#
#
# H1:   ['accessibility', 'link', 'search', 'mode', 'search', 'result', 'page', 'navigation', 'footer', 'link']
#
# H2:   ['web', 'result', 'link', 'web', 'result', 'twitter', 'result', 'web', 'result', 'complementary', 'result', 'tensorflow']
#
# H3:   ['tensorflow', 'tutorial', 'install', 'tensorflow', 'core', 'learn', 'javascript', 'ask', 'tensorflowtensorflow', 'source', 'machine', 'github', 'tensorflow', 'wikipedia', 'tensorflow', 'twitter', 'tensorflow', 'deeplearningai', 'tensorflow', 'developer', 'certificate', 'relate', 'search', 'image', 'description']
#
# H4:   []
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'ask', 'tensorflow', 'tensorflow', 'python', 'tensorflow', '-PRON-', 'learn', 'tensorflow', 'keras', 'tensorflow', 'tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'wiki', 'tensorflow', 'tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'analytics', 'magazine', 'hour', 'ago', 'week', 'ago', 'news', 'news', 'tensorflow ™', 'source', 'software', 'library', 'numerical', 'computation', 'datum', 'flow', 'graphs', 'node', 'graph', 'represent', 'mathematical', 'operation', 'machine', 'learn', 'tensorflow', 'indemand', 'popular', 'opensource', 'deep', 'learn', 'frameworks', 'available', 'deeplearningai', 'developer', 'view', 'relate', 'search', 'tensorflow', 'tutorial', 'tensorflow', 'js', 'page', 'navigation', 'tensorflow', 'software', 'tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'particular', 'focus', 'training', 'inference', 'deep', 'neural', 'network', 'wikipedia', 'platform', 'linux', 'macos', 'windows', 'android', 'javascript', 'license', 'apache', 'license', 'developer', 'google', 'brain', 'write', 'python', 'cuda', 'initial', 'release', 'ago', 'stable', 'release', '261', '2021', 'ago', 'month', 'salary', 'release', 'capability', 'view', '45', 'view', 'feedback', 'jamaica', 'hill', 'boston', 'ma', '-PRON-', 'ip', 'address', '-PRON-', 'ip', 'address', 'helpsend', 'feedbackprivacyterm', 'helpsend', 'feedbackprivacyterm']
#
# P:   ['hour', 'ago', 'week', 'ago']
#
# URL INDEX:  6   LABEL:  WORK
# URL:  https://www.google.com/search?q=tensorflow&sxsrf=AOaemvJ8jbtZUJNPMoLhigUIZ59MRlAoQw%3A1638520683572&ei=a9epYYCyIoulptQPxayFcA&oq=tensor+flow&gs_lcp=&sclient=gws-wiz
#
#
# H1:   ['accessibility', 'link', 'search', 'mode', 'search', 'result', 'page', 'navigation', 'footer', 'link']
#
# H2:   ['web', 'result', 'link', 'web', 'result', 'twitter', 'result', 'web', 'result', 'complementary', 'result', 'tensorflow']
#
# H3:   ['tensorflow', 'tutorial', 'install', 'tensorflow', 'core', 'learn', 'javascript', 'ask', 'tensorflowtensorflow', 'source', 'machine', 'github', 'tensorflow', 'wikipedia', 'tensorflow', 'twitter', 'tensorflow', 'deeplearningai', 'tensorflow', 'developer', 'certificate', 'relate', 'search', 'image', 'description']
#
# H4:   []
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'ask', 'tensorflow', 'tensorflow', 'python', 'tensorflow', '-PRON-', 'learn', 'tensorflow', 'keras', 'tensorflow', 'tensorflow', 'endtoend', 'source', 'platform', 'machine', 'learn', '-PRON-', 'comprehensive', 'flexible', 'ecosystem', 'tool', 'library', 'wiki', 'tensorflow', 'tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'twitter', 'ago', 'analytics', 'magazine', 'hour', 'ago', 'week', 'ago', 'news', 'news', 'tensorflow ™', 'source', 'software', 'library', 'numerical', 'computation', 'datum', 'flow', 'graphs', 'node', 'graph', 'represent', 'mathematical', 'operation', 'machine', 'learn', 'tensorflow', 'indemand', 'popular', 'opensource', 'deep', 'learn', 'frameworks', 'available', 'deeplearningai', 'developer', 'view', 'relate', 'search', 'tensorflow', 'tutorial', 'tensorflow', 'js', 'page', 'navigation', 'tensorflow', 'software', 'tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'particular', 'focus', 'training', 'inference', 'deep', 'neural', 'network', 'wikipedia', 'platform', 'linux', 'macos', 'windows', 'android', 'javascript', 'license', 'apache', 'license', 'developer', 'google', 'brain', 'write', 'python', 'cuda', 'initial', 'release', 'ago', 'stable', 'release', '261', '2021', 'ago', 'month', 'salary', 'release', 'capability', 'view', '45', 'view', 'feedback', 'jamaica', 'hill', 'boston', 'ma', '-PRON-', 'ip', 'address', '-PRON-', 'ip', 'address', 'helpsend', 'feedbackprivacyterm', 'helpsend', 'feedbackprivacyterm']
#
# P:   ['hour', 'ago', 'week', 'ago']
#
# URL INDEX:  7   LABEL:  WORK
# URL:  https://www.tensorflow.org/tutorials/images/cnn
#
#
# H1:   ['convolutional', 'neural', 'network', 'cnn']
#
# H2:   []
#
# H3:   ['import', 'tensorflow', 'download', 'prepare', 'cifar10', 'dataset', 'verify', 'datum', 'create', 'convolutional', 'base', 'add', 'dense', 'layer', 'compile', 'train', 'model', 'evaluate', 'model', 'stay', 'connect']
#
# H4:   []
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['page', 'page', 'import', 'tensorflow', 'download', 'prepare', 'cifar10', 'dataset', 'verify', 'datum', 'create', 'convolutional', 'base', 'add', 'dense', 'layer', 'compile', 'train', 'model', 'evaluate', 'model', 'import', 'tensorflow', 'tf', 'tensorflow', 'keras', 'import', 'dataset', 'layer', 'model', 'import', 'matplotlib', 'pyplot', 'plt', 'trainimage', 'trainlabel', 'testimage', 'testlabel', 'dataset', 'cifar10', 'loaddata', 'normalize', 'pixel', 'value', 'trainimage', 'testimage', 'trainimage', '2550', 'testimage', '2550', 'classname', 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck', 'plt', 'figure', 'figsize', 'range', 'plt', 'subplot', 'plt', 'xticks', 'plt', 'ytick', 'plt', 'grid', 'false', 'plt', 'imshow', 'trainimage', 'cifar', 'label', 'happen', 'arrays', '-PRON-', 'extra', 'index', 'plt', 'xlabel', 'classname', 'trainlabel', 'plt', 'model', 'model', 'sequential', 'model', 'add', 'layer', 'conv2d', '32', 'activation', 'relu', 'inputshape', '32', '32', 'model', 'add', 'layer', 'maxpooling2d', 'model', 'add', 'layer', 'conv2d', '64', 'activation', 'relu', 'model', 'add', 'layer', 'maxpooling2d', 'model', 'add', 'layer', 'conv2d', '64', 'activation', 'relu', 'model', 'summary', 'model', 'add', 'layer', 'flatten', 'model', 'add', 'layer', 'dense', '64', 'activation', 'relu', 'model', 'add', 'layer', 'dense', 'model', 'summary', 'model', 'compile', 'optimizer', 'adam', 'loss', 'tf', 'keras', 'loss', 'sparsecategoricalcrossentropy', 'fromlogits', 'true', 'metric', 'accuracy', 'model', 'fit', 'trainimage', 'trainlabel', 'epoch', 'validationdata', 'testimage', 'testlabel', 'plt', 'plot', 'accuracy', 'label', 'accuracy', 'plt', 'plot', 'valaccuracy', 'label', 'valaccuracy', 'plt', 'xlabel', 'epoch', 'plt', 'ylabel', 'accuracy', 'plt', 'ylim', '05', 'plt', 'legend', 'loc', 'testloss', 'testacc', 'model', 'evaluate', 'testimage', 'testlabel', 'verbose', 'print', 'testacc', 'sign', 'tensorflow', 'monthly', 'newsletter']
#
# P:   ['tutorial', 'demonstrate', 'training', 'simple', 'convolutional', 'neural', 'network', 'cnn', 'classify', 'cifar', 'image', 'keras', 'sequential', 'api', 'create', '-PRON-', 'model', 'code', 'cifar10', 'dataset', 'contain', '60000', 'color', 'image', '6000', 'divide', '50000', 'training', '10000', 'testing', 'mutually', 'exclusive', 'overlap', '-PRON-', 'verify', 'dataset', 'correct', 'lets', 'plot', 'image', 'training', 'display', 'below', 'code', 'below', 'define', 'convolutional', 'base', 'pattern', 'stack', 'conv2d', 'maxpooling2d', 'layer', 'input', 'cnn', 'tensor', 'shape', 'imageheight', 'imagewidth', 'colorchannel', 'ignore', 'batch', 'size', '-PRON-', 'dimension', 'refer', 'rgb', 'example', 'configure', 'process', '32', 'format', 'cifar', 'image', 'pass', 'argument', 'inputshape', 'layer', 'lets', 'display', 'architecture', '-PRON-', 'model', '-PRON-', 'output', 'conv2d', 'maxpooling2d', 'layer', '3d', 'tensor', 'shape', 'height', 'width', 'channel', 'dimension', 'tend', 'shrink', 'deeply', 'network', 'argument', 'eg', '32', '64', 'typically', 'afford', 'computationally', 'add', 'complete', 'model', '-PRON-', 'feed', 'output', 'tensor', 'convolutional', 'base', 'shape', '64', 'dense', 'layer', 'perform', 'classification', 'vector', 'input', '1d', 'current', '3d', 'flatten', 'unroll', 'add', 'cifar', 'complete', 'architecture', '-PRON-', 'model', 'network', 'summary', '64', 'output', 'flatten', 'vector', 'shape', '1024', 'dense', 'layer', '-PRON-', 'simple', 'cnn', 'achieve', 'test', 'accuracy', '70', 'bad', 'code', 'style', 'check', 'tensorflow', 'quickstart', 'expert', 'example', 'keras', 'subclasse', 'api', 'tfgradienttape', 'except', 'otherwise', 'note', 'content', 'page', 'license', 'creative', 'commons', 'attribution', '40', 'code', 'sample', 'apache', 'detail', 'google', 'developer', 'policy', 'java', 'register', 'trademark', 'oracle', 'andor', '-PRON-', 'affiliate', 'update', '20211111', 'utc']
#
# URL INDEX:  8   LABEL:  WORK
# URL:  https://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/
#
#
# H1:   ['convolutional', 'layer', 'deep', 'learn', 'neural', 'network']
#
# H2:   ['tutorial', 'overview', 'convolution', 'convolutional', 'neural', 'network', 'convolution', 'computer', 'vision', 'learn', 'filter', 'example', 'convolutional', 'layer', 'read', 'summary', 'develop', 'deep', 'learn', 'model', 'vision']
#
# H3:   ['result', 'deep', 'learn', 'computer', 'vision', 'multiple', 'filter', 'multiple', 'channel', 'multiple', 'layer', 'example', '1d', 'convolutional', 'layer', 'example', '2d', 'convolutional', 'layer', 'api', 'topic', '71', 'response', 'convolutional', 'layer', 'deep', 'learn', 'neural', 'network', 'reply']
#
# H4:   ['develop', '-PRON-', 'vision', 'model', 'minute', 'bring', 'deep', 'learn', '-PRON-', 'vision', 'jason', 'brownlee', 'miss', 'tutorial', 'pick', '-PRON-', 'tutorial']
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['jason', 'brownlee', 'jason', 'brownlee', 'deep', 'learn', 'computer', 'vision', 'share', 'share', 'define', 'input', 'datum', 'datum', 'asarray', 'datum', 'datum', 'reshape', 'create', 'model', 'model', 'sequential', 'model', 'add', 'conv1d', 'inputshape', 'define', 'vertical', 'detector', 'weight', 'asarray', 'asarray', '00', 'store', 'weight', 'model', 'model', 'setweight', 'weight', 'confirm', '-PRON-', 'store', 'print', 'model', 'getweight', 'apply', 'filter', 'input', 'datum', 'yhat', 'model', 'predict', 'datum', 'print', 'yhat', 'example', 'calculation', '1d', 'convolution', 'numpy', 'import', 'asarray', 'keras', 'model', 'import', 'sequential', 'keras', 'layer', 'import', 'conv1d', 'define', 'input', 'datum', 'datum', 'asarray', 'datum', 'datum', 'reshape', 'create', 'model', 'model', 'sequential', 'model', 'add', 'conv1d', 'inputshape', 'define', 'vertical', 'detector', 'weight', 'asarray', 'asarray', '00', 'store', 'weight', 'model', 'model', 'setweight', 'weight', 'confirm', '-PRON-', 'store', 'print', 'model', 'getweight', 'apply', 'filter', 'input', 'datum', 'yhat', 'model', 'predict', 'datum', 'print', 'yhat', 'numpy', 'import', 'asarray', 'print', 'asarray', 'dot', 'asarray', 'define', 'input', 'datum', 'datum', 'datum', 'asarray', 'datum', 'datum', 'datum', 'reshape', 'create', 'model', 'model', 'sequential', 'model', 'add', 'conv2d', 'inputshape', 'define', 'vertical', 'detector', 'detector', 'weight', 'asarray', 'detector', 'asarray', '00', 'store', 'weight', 'model', 'model', 'setweight', 'weight', 'confirm', '-PRON-', 'store', 'print', 'model', 'getweight', 'apply', 'filter', 'input', 'datum', 'yhat', 'model', 'predict', 'datum', 'range', 'yhat', 'shape', 'print', 'column', 'row', 'print', 'yhat', 'range', 'yhat', 'shape', 'example', 'calculation', '2d', 'convolution', 'numpy', 'import', 'asarray', 'keras', 'model', 'import', 'sequential', 'keras', 'layer', 'import', 'conv2d', 'define', 'input', 'datum', 'datum', 'datum', 'asarray', 'datum', 'datum', 'datum', 'reshape', 'create', 'model', 'model', 'sequential', 'model', 'add', 'conv2d', 'inputshape', 'define', 'vertical', 'detector', 'detector', 'weight', 'asarray', 'detector', 'asarray', '00', 'store', 'weight', 'model', 'model', 'setweight', 'weight', 'confirm', '-PRON-', 'store', 'print', 'model', 'getweight', 'apply', 'filter', 'input', 'datum', 'yhat', 'model', 'predict', 'datum', 'range', 'yhat', 'shape', 'print', 'column', 'row', 'print', 'yhat', 'range', 'yhat', 'shape', 'numpy', 'import', 'asarray', 'numpy', 'import', 'tensordot', 'm1', 'asarray', 'm2', 'asarray', 'print', 'tensordot', 'm1', 'm2', 'what s', 'share', 'share', 'gentle', 'introduction', 'pool', 'layer', 'for …', 'attention', 'encoderdecoder', 'recurrent …', 'crash', 'convolutional', 'neural', 'network', 'for …', 'handwritten', 'digit', 'recognition', 'convolutional …', 'convolutional', 'neural', 'network', 'multistep', 'time …', 'deeplearningai', 'convolutional', 'neural', 'network', 'course …', 'shaheen', 'alhirmizy', '2019', '436', 'pm', 'jason', 'brownlee', '2019', '731', 'prisilla', '2019', '1246', 'jason', 'brownlee', '2019', '824', 'prisilla', '2019', '133', '2019', '254', 'pm', 'jason', 'brownlee', '29', '2019', '815', 'rasmus', 'hartvig', '2019', '819', 'pm', 'jason', 'brownlee', '2019', '627', 'noushin', '2019', '750', 'pm', 'jason', 'brownlee', '2019', '618', 'sung', '2020', '742', 'pm', 'jason', 'brownlee', '2020', '618', 'noushin', '2019', '657', 'pm', 'jason', 'brownlee', '2019', '637', 'ami', '2020', '713', 'jason', 'brownlee', '2020', '740', 'vishnu', '2020', '558', 'jason', 'brownlee', '2020', '135', 'pm', 'ohood', 'fadil', '2020', '1006', 'pm', 'jason', 'brownlee', '2020', '555', 'yogeeshwari', '2020', '331', 'jason', 'brownlee', '2020', '623', 'hanan', '2020', '656', 'jason', 'brownlee', '2020', '141', 'pm', 'kasjan', '29', '2020', '730', 'pm', 'jason', 'brownlee', '2020', '641', 'alok', '2020', '911', 'pm', 'jason', 'brownlee', '2020', '620', 'zi', '2020',  ...
#
# P:   ['update', '2020', 'convolutional', 'layer', 'build', 'blocks', 'neural', 'network', 'convolution', 'simple', 'application', 'filter', 'input', 'result', 'activation', 'repeat', 'map', 'feature', 'indicate', 'location', 'strength', 'detect', 'image', 'innovation', 'convolutional', 'neural', 'network', 'ability', 'automatically', 'learn', 'filter', 'parallel', 'specific', 'training', 'dataset', 'constraint', 'predictive', 'model', 'problem', 'image', 'classification', 'result', 'highly', 'feature', 'detect', 'anywhere', 'input', 'tutorial', '-PRON-', 'discover', 'convolution', 'convolutional', 'neural', 'network', 'complete', 'tutorial', '-PRON-', 'kickstart', '-PRON-', 'deep', 'learn', 'computer', 'vision', 'stepbystep', 'tutorial', 'python', 'source', 'code', 'file', 'example', 'start', 'gentle', 'introduction', 'convolutional', 'layer', 'deep', 'learn', 'neural', 'network', 'photo', 'mendhak', 'reserved', 'tutorial', 'divide', '-PRON-', '-PRON-', '7day', 'email', 'crash', 'sample', 'code', 'click', 'signup', 'pdf', 'ebook', 'click', 'subscribe', 'convolutional', 'neural', 'network', 'cnn', 'specialized', 'type', 'model', 'twodimensional', 'image', 'datum', '-PRON-', 'onedimensional', 'threedimensional', 'convolutional', 'neural', 'network', 'layer', '-PRON-', 'perform', 'operation', 'convolution', 'context', 'convolutional', 'neural', 'network', 'convolution', 'linear', 'operation', 'involve', 'multiplication', 'weight', 'input', 'traditional', 'technique', 'twodimensional', 'perform', 'array', 'datum', 'filter', 'kernel', 'filter', 'input', 'datum', 'type', 'multiplication', 'apply', 'filtersize', 'patch', 'dot', 'product', 'elementwise', 'sum', 'result', 'value', '-PRON-', 'operation', 'refer', 'scalar', 'filter', 'input', 'intentional', '-PRON-', 'allow', 'weight', 'multiply', 'array', 'multiple', 'specifically', 'apply', 'systematically', 'overlap', 'filtersize', 'patch', 'datum', 'bottom', 'systematic', 'application', 'filter', 'image', 'powerful', 'idea', 'detect', 'specific', 'type', 'feature', 'input', 'systematically', 'entire', 'allow', 'opportunity', 'discover', 'anywhere', 'capability', 'commonly', 'refer', 'translation', 'invariance', 'eg', 'interest', 'whether', 'rather', '-PRON-', 'invariance', 'translation', 'useful', 'property', '-PRON-', 'care', 'whether', 'feature', 'exactly', 'example', 'determine', 'image', 'contain', 'location', 'eye', 'pixelperfect', 'accuracy', 'page', '342', 'deep', 'learn', 'output', 'multiply', 'filter', 'input', 'array', 'value', 'apply', 'multiple', 'result', 'twodimensional', 'represent', 'operation', 'feature', 'map', 'feature', 'map', 'create', '-PRON-', 'pass', 'value', 'nonlinearity', 'relu', 'output', 'fully', 'connect', 'layer', 'example', 'filter', 'apply', 'twodimensional', 'input', 'create', 'feature', 'map', '-PRON-', 'digital', 'signal', 'processing', 'relate', 'mathematic', 'understand', 'convolution', 'operation', 'matrix', 'specifically', 'filter', 'kernel', 'flip', 'prior', 'apply', 'input', 'technically', 'describe', 'convolutional', 'neural', 'network', 'actually', 'crosscorrelation', 'nevertheless', 'deep', 'learn', 'refer', 'machine', 'learn', 'library', 'implement', 'crosscorrelation', '-PRON-', 'convolution', 'page', '333', 'deep', 'learn', 'summary', '-PRON-', 'input', 'image', 'pixel', 'value', 'filter', 'weight', 'systematically', 'apply', 'datum', 'create', 'feature', 'map', 'idea', 'apply', 'convolutional', 'operation', 'image', 'datum', 'unique', 'neural', 'network', '-PRON-', 'technique', 'computer', 'vision', 'historically', 'filter', 'computer', 'vision', 'expert', 'apply', 'image', 'result', 'feature', 'map', 'output', 'analysis', 'easy', 'example', 'below', 'craft', '3×3', 'element', 'filter', 'detect', 'vertical', 'apply', 'filter', 'image', 'result', 'feature', 'map', 'contain', 'vertical', '-PRON-', 'detector', '-PRON-', 'weight', 'value', 'filter', 'pixel', 'vertical', 'positively', 'activate', 'negatively', 'drag', 'systematically', 'ima ...
#
# URL INDEX:  9   LABEL:  WORK
# URL:  https://www.ibm.com/cloud/learn/convolutional-neural-networks
#
#
# H1:   ['convolutional', 'neural', 'network', 'convolutional', 'neural', 'network']
#
# H2:   ['convolutional', 'neural', 'network', 'convolutional', 'neural', 'network', 'type', 'convolutional', 'neural', 'network', 'convolutional', 'neural', 'network', 'computer', 'vision', 'convolutional', 'neural', 'network', 'ibm']
#
# H3:   ['convolutional', 'layer', 'pool', 'layer', 'fullyconnected', 'layer']
#
# H4:   []
#
# H5:   []
#
# H6:   []
#
# SPAN:   ['contact', '-PRON-', 'convolutional', 'neural', 'network', 'ibm', 'cloud', 'ibm', 'cloud', 'convolutional', 'neural', 'network', 'learn', 'convolutional', 'neural', 'network', 'threedimensional', 'datum', 'image', 'classification', 'object', 'recognition', 'task']
#
# P:   ['reiterate', 'neural', 'network', 'learn', 'hub', 'article', 'subset', 'machine', '-PRON-', 'deep', 'algorithms', 'comprise', 'node', 'layer', 'contain', 'input', 'hide', 'output', 'connect', 'associated', 'weight', 'threshold', 'individual', 'specify', 'value', 'activate', 'send', 'datum', 'otherwise', 'pass', '-PRON-', 'primarily', 'focus', 'feedforward', 'network', 'article', 'type', 'neural', 'net', 'datum', 'example', 'recurrent', 'commonly', 'natural', 'processing', 'speech', 'recognition', 'whereas', 'convolutional', 'convnets', 'cnns', 'utilize', 'classification', 'computer', 'vision', 'task', 'prior', 'manual', 'timeconsuming', 'feature', 'extraction', 'method', 'identify', 'object', 'image', 'provide', 'scalable', 'approach', 'leverage', 'principle', 'linear', 'algebra', 'specifically', 'matrix', 'multiplication', 'pattern', 'computationally', 'demand', 'require', 'graphical', 'unit', 'gpus', 'train', 'model', 'convolutional', 'neural', 'network', 'distinguished', '-PRON-', 'superior', 'performance', 'image', 'speech', 'audio', 'signal', 'input', 'type', 'layer', 'convolutional', 'layer', 'network', 'follow', 'additional', 'pool', 'fullyconnected', 'cnn', 'increase', '-PRON-', 'complexity', 'identify', 'portion', 'image', 'focus', 'simple', 'feature', 'color', 'edges', 'datum', 'progress', 'start', 'recognize', 'element', 'shapes', 'object', 'identifies', 'intend', 'convolutional', 'layer', 'core', 'build', 'block', 'cnn', '-PRON-', 'majority', 'computation', 'occur', 'require', 'component', 'input', 'datum', 'filter', 'feature', 'map', 'assume', 'color', 'image', 'matrix', 'pixel', '3d', 'mean', 'dimension — a', 'height', 'width', 'depth — which', 'correspond', 'rgb', 'detector', 'kernel', 'receptive', 'check', 'process', 'convolution', 'feature', 'detector', 'twodimensional', '2d', 'array', 'weight', 'represent', 'image', '-PRON-', 'vary', 'size', 'filter', 'typically', '3x3', 'matrix', 'determine', 'receptive', 'apply', 'dot', 'product', 'calculate', 'input', 'pixel', 'fed', 'output', 'afterwards', 'shift', 'stride', 'repeat', 'process', 'kernel', 'sweep', 'entire', 'map', 'activation', 'convolve', '-PRON-', 'image', 'output', 'value', 'feature', 'map', 'connect', 'pixel', 'input', 'receptive', 'filter', 'apply', 'array', 'directly', 'convolutional', 'pool', 'layer', 'commonly', 'refer', 'partially', 'characteristic', 'describe', 'connectivity', 'note', 'weight', 'feature', 'detector', 'remain', 'fix', '-PRON-', 'image', 'parameter', 'share', 'value', 'adjust', 'training', 'process', 'backpropagation', 'gradient', 'descent', 'hyperparameter', 'affect', 'volume', 'size', 'output', 'neural', 'network', 'begin', 'filter', 'affect', 'depth', 'output', 'example', 'distinct', 'yield', 'feature', 'map', 'create', 'stride', 'distance', 'pixel', 'kernel', 'input', 'matrix', 'value', 'rare', 'yield', 'output', 'zeropadde', 'usually', 'filter', 'fit', 'input', 'image', 'element', 'fall', 'matrix', 'zero', 'produce', 'equally', 'sized', 'output', 'type', 'padding', 'convolution', 'operation', 'cnn', 'apply', 'rectified', 'linear', 'unit', 'relu', 'transformation', 'feature', 'map', 'introduce', 'nonlinearity', 'model', '-PRON-', 'mention', 'convolution', 'layer', 'follow', 'initial', 'happen', 'structure', 'cnn', 'hierarchical', 'pixel', 'receptive', 'prior', 'example', 'assume', 'try', 'determine', 'image', 'contain', 'bicycle', 'sum', 'comprise', 'frame', 'handlebar', 'wheel', 'pedal', 'et', 'cetera', 'individual', 'lowerlevel', 'pattern', 'neural', 'net', 'combination', 'represent', 'higherlevel', 'create', 'feature', 'hierarchy', 'ultimately', 'convolutional', 'layer', 'convert', 'image', 'numerical', 'value', 'allow', 'neural', 'network', 'interpret', 'extract', 'relevant', 'pattern', 'pool', 'layer', 'downsample', 'conduct', 'dimensionality', 'reduction', 'reduce', 'parameter', 'input', 'similar', 'convolutional', 'operation', 'sweep', 'filter', 'entire', 'difference', 'weight', 'kernel', 'apply', 'aggregation', ' ...
#
# URL INDEX:  10   LABEL:  WORK

# %%
for index, row in history.iterrows():
    if index>=10:
        break
    print("URL INDEX: ", index, "ROW: ",np.array(list(row['H1'])))
# Out:
# URL INDEX:  0 ROW:  ['convolutional' 'neural' 'network' 'cnn']
# URL INDEX:  1 ROW:  []
# URL INDEX:  2 ROW:  ['tensorflow']
# URL INDEX:  3 ROW:  ['tensorflow']
# URL INDEX:  4 ROW:  []
# URL INDEX:  5 ROW:  ['accessibility' 'link' 'search' 'mode' 'search' 'result' 'page'
#  'navigation' 'footer' 'link']
# URL INDEX:  6 ROW:  ['accessibility' 'link' 'search' 'mode' 'search' 'result' 'page'
#  'navigation' 'footer' 'link']
# URL INDEX:  7 ROW:  ['convolutional' 'neural' 'network' 'cnn']
# URL INDEX:  8 ROW:  ['convolutional' 'layer' 'deep' 'learn' 'neural' 'network']
# URL INDEX:  9 ROW:  ['convolutional' 'neural' 'network' 'convolutional' 'neural' 'network']

# %%
skill_rare_words = []
for i, skill in skills_df.iterrows():
    skill_rare_words.extend(skill['rare_words'])
print(skill_rare_words)
# Out:
# ['deep', 'learn', 'structure', 'broad', 'machine', 'method', 'base', 'artificial', 'neural', 'network', 'representation', 'supervise', 'semisupervised', 'unsuperviseddeeplearne', 'architecture', 'belief', 'reinforcement', 'recurrent', 'convolutional', 'apply', 'computer', 'vision', 'speech', 'recognition', 'natural', 'processing', 'translation', 'bioinformatics', 'drug', 'medical', 'image', 'analysis', 'material', 'inspection', '-PRON-', 'produce', 'result', 'comparable', 'surpass', 'expert', 'performanceartificial', 'anns', 'inspire', 'distribute', 'communication', 'node', 'biological', 'difference', 'brain', 'specifically', 'tend', 'static', 'symbolic', 'organism', 'dynamic', 'plastic', 'analoguethe', 'adjective', 'refer', 'multiple', 'layer', 'linear', 'perceptron', 'universal', 'classifier', 'nonpolynomial', 'activation', 'function', 'hide', 'unbounded', 'width', 'modern', 'variation', 'concerned', 'bound', 'size', 'permits', 'practical', 'application', 'optimize', 'implementation', 'retain', 'theoretical', 'universality', 'mild', 'condition', 'permit', 'heterogeneous', 'deviate', 'widely', 'biologically', 'inform', 'connectionist', 'model', 'sake', 'efficiency', 'trainability', 'understandability', 'whence', 'deep', 'learn', 'convolutional', 'neural', 'network', 'cnn', 'convnet', 'artificial', 'commonly', 'apply', 'analyze', 'visual', 'imagery', '-PRON-', 'shift', 'invariant', 'siann', 'base', 'sharedweight', 'architecture', 'convolution', 'kernel', 'filter', 'slide', 'input', 'feature', 'provide', 'translation', 'equivariant', 'response', 'map', 'counterintuitively', 'oppose', 'application', 'image', 'recognition', 'recommender', 'classification', 'segmentation', 'medical', 'analysis', 'natural', 'processing', 'braincomputer', 'interface', 'financial', 'seriescnns', 'regularize', 'multilayer', 'perceptron', 'usually', 'mean', 'fully', 'connect', 'neuron', 'layer', 'connectivity', 'prone', 'overfitting', 'datum', 'typical', 'ways', 'regularization', 'prevent', 'penalize', 'parameter', 'training', 'weight', 'decay', 'trim', 'skipped', 'connection', 'dropout', 'etc', 'cnns', 'approach', 'towards', 'advantage', 'hierarchical', 'pattern', 'assemble', 'increase', 'complexity', 'simple', 'emboss', 'therefore', 'scale', 'extreme', 'inspire', 'biological', 'process', 'resemble', 'organization', 'animal', 'cortex', 'individual', 'cortical', 'respond', 'stimuli', 'restrict', 'receptive', 'partially', 'overlap', 'cover', 'entire', 'relatively', 'preprocesse', 'compare', 'algorithms', 'learns', 'optimize', 'automate', 'whereas', 'traditional', 'handengineere', 'independence', 'prior', 'knowledge', 'intervention', 'extraction', 'tensorflow', 'opensource', 'software', 'library', 'machine', 'learn', 'artificial', 'intelligence', '-PRON-', 'range', 'task', 'particular', 'focus', 'training', 'inference', 'deep', 'neural', 'networkstensorflow', 'develop', 'google', 'brain', 'internal', 'initial', 'release', 'apache', 'license', 'update', '2019tensorflow', 'wide', 'variety', 'programming', 'notably', 'python', 'javascript', 'java', 'flexibility', 'lend', 'application', 'sector', 'machine', 'learn', 'ml', 'study', 'computer', 'algorithms', 'improve', 'automatically', 'experience', 'datum', '-PRON-', 'artificial', 'intelligence', 'build', 'model', 'base', 'sample', 'training', 'prediction', 'decision', 'explicitly', 'wide', 'variety', 'application', 'medicine', 'email', 'filter', 'speech', 'recognition', 'vision', 'difficult', 'unfeasible', 'develop', 'conventional', 'perform', 'tasksa', 'subset', 'closely', 'relate', 'computational', 'statistic', 'focus', 'statistical', 'mathematical', 'optimization', 'deliver', 'method', 'theory', 'domain', 'mining', 'exploratory', 'analysis', 'unsupervise', 'implementation', 'neural', 'network', 'mimics', 'biological', 'brain', 'problem', 'refer', 'predictive', 'analytics', 'mathematic', 'computer', 'algorithm', 'listen', 'finite', 'sequence', 'welldefine', 'instruction', 'typically', 'solve', 'specific',  ...

# %%
def word_match_count(skill_list, fetched_list):
    count = 0
    for word in fetched_list:
        if word in skill_list:
            count = count + fetched_list[word]
        if debug:
            print(word)
    return count

def percent_word_count_match(skill_list, fetched_list):
    count = word_match_count(skill_list,fetched_list)
    if count > 0 and len(fetched_list) > 0:
        return (count/len(fetched_list)) * 100
    else:
        return 0

# %%
debug = False
for index, row in history.iterrows():
    if index>=10:
        break
    print("\nURL INDEX: ", index, "  Label: ", row['LABEL'] )
    h1 = Counter(row['H1'])
    h2 = Counter(row['H2'])
    h3 = Counter(row['H3'])
    h4 = Counter(row['H4'])
    h5 = Counter(row['H5'])
    h6 = Counter(row['H6'])
    span = Counter(row['SPAN'])
    p = Counter(row['p'])
    print("\nH1 :", percent_word_count_match(skill_rare_words, h1))
    print("H2 :", percent_word_count_match(skill_rare_words, h2))
    print("H3 :", percent_word_count_match(skill_rare_words, h3))
    print("H4 :", percent_word_count_match(skill_rare_words, h4))
    print("H5 :", percent_word_count_match(skill_rare_words, h5))
    print("H6 :", percent_word_count_match(skill_rare_words, h6))
    print("SPAN :", percent_word_count_match(skill_rare_words, span))
    print("P :", percent_word_count_match(skill_rare_words, p))

# %%
def test_url(url):
    try:
        (h1,h2,h3,h4,h5,h6,span,p) = process_url(url)
        rare_words_h1 = extract_rare_words_from_sel_objects(h1)
        rare_words_h2 = extract_rare_words_from_sel_objects(h2)
        rare_words_h3 = extract_rare_words_from_sel_objects(h3)
        rare_words_h4 = extract_rare_words_from_sel_objects(h4)
        rare_words_h5 = extract_rare_words_from_sel_objects(h5)
        rare_words_h6 = extract_rare_words_from_sel_objects(h6)
        rare_words_span = extract_rare_words_from_sel_objects(span)
        rare_words_p = extract_rare_words_from_sel_objects(p)
        h1 = Counter(rare_words_h1)
        h2 = Counter(rare_words_h2)
        h3 = Counter(rare_words_h3)
        h4 = Counter(rare_words_h4)
        h5 = Counter(rare_words_h5)
        h6 = Counter(rare_words_h6)
        span = Counter(rare_words_span)
        p = Counter(rare_words_p)
        print("\nH1 :", percent_word_count_match(skill_rare_words, h1))
        print("H2 :", percent_word_count_match(skill_rare_words, h2))
        print("H3 :", percent_word_count_match(skill_rare_words, h3))
        print("H4 :", percent_word_count_match(skill_rare_words, h4))
        print("H5 :", percent_word_count_match(skill_rare_words, h5))
        print("H6 :", percent_word_count_match(skill_rare_words, h6))
        print("SPAN :", percent_word_count_match(skill_rare_words, span))
        print("P :", percent_word_count_match(skill_rare_words, p))
    except:
        print("Thrown Exception at testing the url")

# %%
debug = False
print("\nURL 1 Score: ")
# False
test_url("https://www.gov.uk/uk-border-control") # travel website
print("\nURL 2 Score: ")
# True
test_url("https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/") # About GANs, which is not one of the scraped skills
print("\nURL 3 Score: ")
# True
test_url("https://builtin.com/robotics") # About Robotics, not listed skill but related
print("\nURL 4 Score: ")
# False - Stock market not related to my skills 
test_url("https://www.financialexpress.com/market/icici-bank-hdfc-tata-motors-among-top-stock-ideas-from-jefferies-expect-around-30-returns/2378875/")

# %%
other_url_df = pd.read_excel("../data/web_history/other_website_history_xl.xls")
other_url_df.head()
other_urls = list(other_url_df["URL"])

# %%
for i, url in enumerate(other_urls):
    print("Index: ",i)
    test_url(url)
    if i >= 100:
        break
